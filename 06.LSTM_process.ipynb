# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import math
import mediapipe as mp

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# %%
# 포즈 감지 함수
def detectPose(image,pose,display=True):
    # input 이미지 복사
    output_image = image.copy()
    # RGB로 변환
    imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    # 렌드마크 찍기
    results = pose.process(imageRGB)
    # 사진 사이즈 구하기
    height, width, _ = image.shape
    # 렌드마크 값 리스트 만들기
    landmarks = []
    visible = []
    if results.pose_landmarks:
        # 렌드마크 그리기
        mp_drawing.draw_landmarks(image=output_image, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)
        #렌드마크 정규값 landmarks 리스트에 넣기
        for landmark in results.pose_landmarks.landmark:
            landmarks.append((int(landmark.x*width), int(landmark.y*height), (landmark.z*width)))
            visible.append(landmark.visibility)
    # 사진 결과 보기
    if display:
        plt.figure(figsize=[22,22])
        plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
        plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');
        # 3차원으로도 봐보기
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)
    else:
        return output_image, landmarks , visible

# %%
def draw_landmarks(image,results):
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)

# %%
def extract_landmarks(results):
    poses_landmarks = np.array([[res.x,res.y,res.z,res.visibility]for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    return poses_landmarks

# %%
# 각도 구하는 함수
def calculateAngle(landmark1, landmark2, landmark3):
    x1,y1,_ = landmark1 # z 좌표는 사용 x
    x2,y2,_ = landmark2
    x3,y3,_ = landmark3
    # 3점의 각도 -> 선 2개 -> 각도
    angle = math.degrees(math.atan2(y3-y2, x3-x2) - math.atan2(y1-y2,x1-x2))

    angle = np.abs(angle)
    # 음수의 각도가 나오면 양수로 바꾸기
    if angle >180.0:
        angle = 360 - angle
        
    return angle

# %%
# 중앙 각도 구하는 함수
def center_Landmark(landmarks1,landmarks2):
    x1,y1,_ = landmarks1
    x2,y2,_ = landmarks2
    x_cen = (x1+x2)/2
    y_cen = (y1+y2)/2
    return x_cen,y_cen,_

# %%
# 데이터를 저장할 경로
data_path = os.path.join('LSTM_PIC')
# landmark를 저장할 경로
data_key = os.path.join('LSTM_DATAS')
# 감지해야 할 액션
actions = np.array(['bend', 'headup', 'right', 'waistup'])
# 30게의 비디오 -> 동영상의 수만큼 수집할 예정
no_sequences = 10

# 동영상의 길이 - 30프레임
sequences_length = 30

# 30개의 동영상  * 30프레임 * 132개의 키포인트

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            #os.makedirs(os.path.join(data_path,action,str(sequence)))
            os.makedirs(os.path.join(data_key,action,str(sequence)))
        except:
            pass

# %%
# 이미 있는 사진으로 data 만들기 
#no_sequences = 10 -> 폴더수  sequences_length = 30 -> 사진수
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:
    for action in actions:
        for sequence in range(no_sequences):
            for frame_num in range(sequences_length):
                print(f'./LSTM_PIC/{action}/{sequence}/'+os.listdir(f'./LSTM_PIC/{action}/{sequence}')[frame_num])
                frame = cv2.imread(f'./LSTM_PIC/{action}/{sequence}/'+os.listdir(f'./LSTM_PIC/{action}/{sequence}')[frame_num])
                
                image, landmarks, visible = detectPose(frame, pose, display=False)
                if landmarks:
                    # 랜드마크 추출 후 각도 계산
                    # visible 가져오기
                    left_shoulder = visible[mp_pose.PoseLandmark.LEFT_SHOULDER.value]
                    right_shoulder = visible[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]
                    left_hip = visible[mp_pose.PoseLandmark.LEFT_HIP.value]
                    right_hip = visible[mp_pose.PoseLandmark.RIGHT_HIP.value]
                    left_knee = visible[mp_pose.PoseLandmark.LEFT_KNEE.value]
                    right_knee = visible[mp_pose.PoseLandmark.RIGHT_KNEE.value]
                    left_ankle = visible[mp_pose.PoseLandmark.LEFT_ANKLE.value]
                    right_ankle = visible[mp_pose.PoseLandmark.RIGHT_ANKLE.value]
                    
                    # 어깨 - 엉덩이 - 무릎 => 올리는 동작 각도 구하기 위함 -> Main angle
                    if left_hip>right_hip:
                        main_angle = calculateAngle(landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value],
                                                            landmarks[mp_pose.PoseLandmark.LEFT_HIP.value],
                                                            landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value])
                    else:
                        main_angle = calculateAngle(landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value],
                                                            landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value],
                                                            landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value])                                                    
                    
                    # 엉덩이 - 무릎 - 발목 => 무릎 꺾였는지 보기 위함
                    if left_knee > right_knee:
                        knee_angle = calculateAngle(landmarks[mp_pose.PoseLandmark.LEFT_HIP.value],
                                                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value],
                                                        landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value])
                    else:
                        knee_angle = calculateAngle(landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value],
                                                        landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value],
                                                        landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value])
                                                        
                    # 어깨 허리  중앙값
                    cen_shoulder = center_Landmark(landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value],
                                                landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value])
                    cen_hip = center_Landmark(landmarks[mp_pose.PoseLandmark.LEFT_HIP.value],
                                            landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value])
                
                    # 코 - 어깨 - 엉덩이 => 목 각도
                    head_angle = calculateAngle(landmarks[mp_pose.PoseLandmark.NOSE.value],
                                                cen_shoulder,cen_hip)

                    # 엉덩이 중앙의 y좌표와 중앙어깨의 y 좌표사이의 거리 
                    waist_len = cen_hip[1]-cen_shoulder[1]
                
                    globals()[f'f{action,frame_num}'] = knee_angle,head_angle,waist_len
                
                    npy_path = os.path.join(data_key, action, str(sequence), str(f'f{action,frame_num}'))
                    # npy_path -> ./MP_Data/action(right,headup,leg)/0~10/0~30
                    np.save(npy_path, globals()[f'f{action,frame_num}'])

            
cv2.destroyAllWindows()
# Out:
# ./LSTM_PIC/bend/0/E-1 (1).jpg
# ./LSTM_PIC/bend/0/E-1 (10).jpg
# ./LSTM_PIC/bend/0/E-1 (11).jpg
# ./LSTM_PIC/bend/0/E-1 (12).jpg
# ./LSTM_PIC/bend/0/E-1 (13).jpg
# ./LSTM_PIC/bend/0/E-1 (14).jpg
# ./LSTM_PIC/bend/0/E-1 (15).jpg
# ./LSTM_PIC/bend/0/E-1 (16).jpg
# ./LSTM_PIC/bend/0/E-1 (17).jpg
# ./LSTM_PIC/bend/0/E-1 (18).jpg
# ./LSTM_PIC/bend/0/E-1 (19).jpg
# ./LSTM_PIC/bend/0/E-1 (2).jpg
# ./LSTM_PIC/bend/0/E-1 (20).jpg
# ./LSTM_PIC/bend/0/E-1 (21).jpg
# ./LSTM_PIC/bend/0/E-1 (22).jpg
# ./LSTM_PIC/bend/0/E-1 (23).jpg
# ./LSTM_PIC/bend/0/E-1 (24).jpg
# ./LSTM_PIC/bend/0/E-1 (25).jpg
# ./LSTM_PIC/bend/0/E-1 (26).jpg
# ./LSTM_PIC/bend/0/E-1 (27).jpg
# ./LSTM_PIC/bend/0/E-1 (28).jpg
# ./LSTM_PIC/bend/0/E-1 (29).jpg
# ./LSTM_PIC/bend/0/E-1 (3).jpg
# ./LSTM_PIC/bend/0/E-1 (30).jpg
# ./LSTM_PIC/bend/0/E-1 (4).jpg
# ./LSTM_PIC/bend/0/E-1 (5).jpg
# ./LSTM_PIC/bend/0/E-1 (6).jpg
# ./LSTM_PIC/bend/0/E-1 (7).jpg
# ./LSTM_PIC/bend/0/E-1 (8).jpg
# ./LSTM_PIC/bend/0/E-1 (9).jpg
# ./LSTM_PIC/bend/1/O-1 (1).jpg
# ./LSTM_PIC/bend/1/O-1 (10).jpg
# ./LSTM_PIC/bend/1/O-1 (11).jpg
# ./LSTM_PIC/bend/1/O-1 (12).jpg
# ./LSTM_PIC/bend/1/O-1 (13).jpg
# ./LSTM_PIC/bend/1/O-1 (14).jpg
# ./LSTM_PIC/bend/1/O-1 (15).jpg
# ./LSTM_PIC/bend/1/O-1 (16).jpg
# ./LSTM_PIC/bend/1/O-1 (17).jpg
# ./LSTM_PIC/bend/1/O-1 (18).jpg
# ./LSTM_PIC/bend/1/O-1 (19).jpg
# ./LSTM_PIC/bend/1/O-1 (2).jpg
# ./LSTM_PIC/bend/1/O-1 (20).jpg
# ./LSTM_PIC/bend/1/O-1 (21).jpg
# ./LSTM_PIC/bend/1/O-1 (22).jpg
# ./LSTM_PIC/bend/1/O-1 (23).jpg
# ./LSTM_PIC/bend/1/O-1 (24).jpg
# ./LSTM_PIC/bend/1/O-1 (25).jpg
# ./LSTM_PIC/bend/1/O-1 (26).jpg
# ./LSTM_PIC/bend/1/O-1 (27).jpg
# ./LSTM_PIC/bend/1/O-1 (28).jpg
# ./LSTM_PIC/bend/1/O-1 (29).jpg
# ./LSTM_PIC/bend/1/O-1 (3).jpg
# ./LSTM_PIC/bend/1/O-1 (30).jpg
# ./LSTM_PIC/bend/1/O-1 (4).jpg
# ./LSTM_PIC/bend/1/O-1 (5).jpg
# ./LSTM_PIC/bend/1/O-1 (6).jpg
# ./LSTM_PIC/bend/1/O-1 (7).jpg
# ./LSTM_PIC/bend/1/O-1 (8).jpg
# ./LSTM_PIC/bend/1/O-1 (9).jpg
# ./LSTM_PIC/bend/2/R (1).jpg
# ./LSTM_PIC/bend/2/R (10).jpg
# ./LSTM_PIC/bend/2/R (11).jpg
# ./LSTM_PIC/bend/2/R (12).jpg
# ./LSTM_PIC/bend/2/R (13).jpg
# ./LSTM_PIC/bend/2/R (14).jpg
# ./LSTM_PIC/bend/2/R (15).jpg
# ./LSTM_PIC/bend/2/R (16).jpg
# ./LSTM_PIC/bend/2/R (17).jpg
# ./LSTM_PIC/bend/2/R (18).jpg
# ./LSTM_PIC/bend/2/R (19).jpg
# ./LSTM_PIC/bend/2/R (2).jpg
# ./LSTM_PIC/bend/2/R (20).jpg
# ./LSTM_PIC/bend/2/R (21).jpg
# ./LSTM_PIC/bend/2/R (22).jpg
# ./LSTM_PIC/bend/2/R (23).jpg
# ./LSTM_PIC/bend/2/R (24).jpg
# ./LSTM_PIC/bend/2/R (25).jpg
# ./LSTM_PIC/bend/2/R (26).jpg
# ./LSTM_PIC/bend/2/R (27).jpg
# ./LSTM_PIC/bend/2/R (28).jpg
# ./LSTM_PIC/bend/2/R (29).jpg
# ./LSTM_PIC/bend/2/R (3).jpg
# ./LSTM_PIC/bend/2/R (30).jpg
# ./LSTM_PIC/bend/2/R (4).jpg
# ./LSTM_PIC/bend/2/R (5).jpg
# ./LSTM_PIC/bend/2/R (6).jpg
# ./LSTM_PIC/bend/2/R (7).jpg
# ./LSTM_PIC/bend/2/R (8).jpg
# ./LSTM_PIC/bend/2/R (9).jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000001.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000002.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000003.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000004.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000005.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000006.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000007.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000008.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000009.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000010.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000011.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000012.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000013.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000014.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000015.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000016.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000017.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000018.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000019.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000020.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000021.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000022.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000023.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000024.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000025.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000026.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000027.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000028.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000029.jpg
# ./LSTM_PIC/bend/3/475-1-2-21-Z3_A-0000030.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000001.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000002.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000003.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000004.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000005.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000006.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000007.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000008.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000009.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000010.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000011.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000012.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000013.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000014.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000015.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000016.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000017.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000018.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000019.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000020.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000021.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000022.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000023.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000024.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000025.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000026.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000027.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000028.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000029.jpg
# ./LSTM_PIC/bend/4/475-1-2-21-Z115_A-0000030.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000001.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000002.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000003.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000004.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000005.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000006.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000007.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000008.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000009.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000010.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000011.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000012.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000013.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000014.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000015.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000016.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000017.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000018.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000019.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000020.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000021.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000022.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000023.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000024.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000025.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000026.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000027.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000028.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000029.jpg
# ./LSTM_PIC/bend/5/475-1-2-21-Z62_A-0000030.jpg
# ./LSTM_PIC/bend/6/A (1).jpg
# ./LSTM_PIC/bend/6/A (10).jpg
# ./LSTM_PIC/bend/6/A (11).jpg
# ./LSTM_PIC/bend/6/A (12).jpg
# ./LSTM_PIC/bend/6/A (13).jpg
# ./LSTM_PIC/bend/6/A (14).jpg
# ./LSTM_PIC/bend/6/A (15).jpg
# ./LSTM_PIC/bend/6/A (16).jpg
# ./LSTM_PIC/bend/6/A (17).jpg
# ./LSTM_PIC/bend/6/A (18).jpg
# ./LSTM_PIC/bend/6/A (19).jpg
# ./LSTM_PIC/bend/6/A (2).jpg
# ./LSTM_PIC/bend/6/A (20).jpg
# ./LSTM_PIC/bend/6/A (21).jpg
# ./LSTM_PIC/bend/6/A (22).jpg
# ./LSTM_PIC/bend/6/A (23).jpg
# ./LSTM_PIC/bend/6/A (24).jpg
# ./LSTM_PIC/bend/6/A (25).jpg
# ./LSTM_PIC/bend/6/A (26).jpg
# ./LSTM_PIC/bend/6/A (27).jpg
# ./LSTM_PIC/bend/6/A (28).jpg
# ./LSTM_PIC/bend/6/A (29).jpg
# ./LSTM_PIC/bend/6/A (3).jpg
# ./LSTM_PIC/bend/6/A (30).jpg
# ./LSTM_PIC/bend/6/A (4).jpg
# ./LSTM_PIC/bend/6/A (5).jpg
# ./LSTM_PIC/bend/6/A (6).jpg
# ./LSTM_PIC/bend/6/A (7).jpg
# ./LSTM_PIC/bend/6/A (8).jpg
# ./LSTM_PIC/bend/6/A (9).jpg
# ./LSTM_PIC/bend/7/B (1).jpg
# ./LSTM_PIC/bend/7/B (10).jpg
# ./LSTM_PIC/bend/7/B (11).jpg
# ./LSTM_PIC/bend/7/B (12).jpg
# ./LSTM_PIC/bend/7/B (13).jpg
# ./LSTM_PIC/bend/7/B (14).jpg
# ./LSTM_PIC/bend/7/B (15).jpg
# ./LSTM_PIC/bend/7/B (16).jpg
# ./LSTM_PIC/bend/7/B (17).jpg
# ./LSTM_PIC/bend/7/B (18).jpg
# ./LSTM_PIC/bend/7/B (19).jpg
# ./LSTM_PIC/bend/7/B (2).jpg
# ./LSTM_PIC/bend/7/B (20).jpg
# ./LSTM_PIC/bend/7/B (21).jpg
# ./LSTM_PIC/bend/7/B (22).jpg
# ./LSTM_PIC/bend/7/B (23).jpg
# ./LSTM_PIC/bend/7/B (24).jpg
# ./LSTM_PIC/bend/7/B (25).jpg
# ./LSTM_PIC/bend/7/B (26).jpg
# ./LSTM_PIC/bend/7/B (27).jpg
# ./LSTM_PIC/bend/7/B (28).jpg
# ./LSTM_PIC/bend/7/B (29).jpg
# ./LSTM_PIC/bend/7/B (3).jpg
# ./LSTM_PIC/bend/7/B (30).jpg
# ./LSTM_PIC/bend/7/B (4).jpg
# ./LSTM_PIC/bend/7/B (5).jpg
# ./LSTM_PIC/bend/7/B (6).jpg
# ./LSTM_PIC/bend/7/B (7).jpg
# ./LSTM_PIC/bend/7/B (8).jpg
# ./LSTM_PIC/bend/7/B (9).jpg
# ./LSTM_PIC/bend/8/X (1).jpg
# ./LSTM_PIC/bend/8/X (10).jpg
# ./LSTM_PIC/bend/8/X (11).jpg
# ./LSTM_PIC/bend/8/X (12).jpg
# ./LSTM_PIC/bend/8/X (13).jpg
# ./LSTM_PIC/bend/8/X (14).jpg
# ./LSTM_PIC/bend/8/X (15).jpg
# ./LSTM_PIC/bend/8/X (16).jpg
# ./LSTM_PIC/bend/8/X (17).jpg
# ./LSTM_PIC/bend/8/X (18).jpg
# ./LSTM_PIC/bend/8/X (19).jpg
# ./LSTM_PIC/bend/8/X (2).jpg
# ./LSTM_PIC/bend/8/X (20).jpg
# ./LSTM_PIC/bend/8/X (21).jpg
# ./LSTM_PIC/bend/8/X (22).jpg
# ./LSTM_PIC/bend/8/X (23).jpg
# ./LSTM_PIC/bend/8/X (24).jpg
# ./LSTM_PIC/bend/8/X (25).jpg
# ./LSTM_PIC/bend/8/X (26).jpg
# ./LSTM_PIC/bend/8/X (27).jpg
# ./LSTM_PIC/bend/8/X (28).jpg
# ./LSTM_PIC/bend/8/X (29).jpg
# ./LSTM_PIC/bend/8/X (3).jpg
# ./LSTM_PIC/bend/8/X (30).jpg
# ./LSTM_PIC/bend/8/X (4).jpg
# ./LSTM_PIC/bend/8/X (5).jpg
# ./LSTM_PIC/bend/8/X (6).jpg
# ./LSTM_PIC/bend/8/X (7).jpg
# ./LSTM_PIC/bend/8/X (8).jpg
# ./LSTM_PIC/bend/8/X (9).jpg
# ./LSTM_PIC/bend/9/I-1 (1).jpg
# ./LSTM_PIC/bend/9/I-1 (10).jpg
# ./LSTM_PIC/bend/9/I-1 (11).jpg
# ./LSTM_PIC/bend/9/I-1 (12).jpg
# ./LSTM_PIC/bend/9/I-1 (13).jpg
# ./LSTM_PIC/bend/9/I-1 (14).jpg
# ./LSTM_PIC/bend/9/I-1 (15).jpg
# ./LSTM_PIC/bend/9/I-1 (16).jpg
# ./LSTM_PIC/bend/9/I-1 (17).jpg
# ./LSTM_PIC/bend/9/I-1 (18).jpg
# ./LSTM_PIC/bend/9/I-1 (19).jpg
# ./LSTM_PIC/bend/9/I-1 (2).jpg
# ./LSTM_PIC/bend/9/I-1 (20).jpg
# ./LSTM_PIC/bend/9/I-1 (21).jpg
# ./LSTM_PIC/bend/9/I-1 (22).jpg
# ./LSTM_PIC/bend/9/I-1 (23).jpg
# ./LSTM_PIC/bend/9/I-1 (24).jpg
# ./LSTM_PIC/bend/9/I-1 (25).jpg
# ./LSTM_PIC/bend/9/I-1 (26).jpg
# ./LSTM_PIC/bend/9/I-1 (27).jpg
# ./LSTM_PIC/bend/9/I-1 (28).jpg
# ./LSTM_PIC/bend/9/I-1 (29).jpg
# ./LSTM_PIC/bend/9/I-1 (3).jpg
# ./LSTM_PIC/bend/9/I-1 (30).jpg
# ./LSTM_PIC/bend/9/I-1 (4).jpg
# ./LSTM_PIC/bend/9/I-1 (5).jpg
# ./LSTM_PIC/bend/9/I-1 (6).jpg
# ./LSTM_PIC/bend/9/I-1 (7).jpg
# ./LSTM_PIC/bend/9/I-1 (8).jpg
# ./LSTM_PIC/bend/9/I-1 (9).jpg
# ./LSTM_PIC/headup/0/H (1).jpg
# ./LSTM_PIC/headup/0/H (10).jpg
# ./LSTM_PIC/headup/0/H (11).jpg
# ./LSTM_PIC/headup/0/H (12).jpg
# ./LSTM_PIC/headup/0/H (13).jpg
# ./LSTM_PIC/headup/0/H (14).jpg
# ./LSTM_PIC/headup/0/H (15).jpg
# ./LSTM_PIC/headup/0/H (16).jpg
# ./LSTM_PIC/headup/0/H (17).jpg
# ./LSTM_PIC/headup/0/H (18).jpg
# ./LSTM_PIC/headup/0/H (19).jpg
# ./LSTM_PIC/headup/0/H (2).jpg
# ./LSTM_PIC/headup/0/H (20).jpg
# ./LSTM_PIC/headup/0/H (21).jpg
# ./LSTM_PIC/headup/0/H (22).jpg
# ./LSTM_PIC/headup/0/H (23).jpg
# ./LSTM_PIC/headup/0/H (24).jpg
# ./LSTM_PIC/headup/0/H (25).jpg
# ./LSTM_PIC/headup/0/H (26).jpg
# ./LSTM_PIC/headup/0/H (27).jpg
# ./LSTM_PIC/headup/0/H (28).jpg
# ./LSTM_PIC/headup/0/H (29).jpg
# ./LSTM_PIC/headup/0/H (3).jpg
# ./LSTM_PIC/headup/0/H (30).jpg
# ./LSTM_PIC/headup/0/H (4).jpg
# ./LSTM_PIC/headup/0/H (5).jpg
# ./LSTM_PIC/headup/0/H (6).jpg
# ./LSTM_PIC/headup/0/H (7).jpg
# ./LSTM_PIC/headup/0/H (8).jpg
# ./LSTM_PIC/headup/0/H (9).jpg
# ./LSTM_PIC/headup/1/F (1).jpg
# ./LSTM_PIC/headup/1/F (10).jpg
# ./LSTM_PIC/headup/1/F (11).jpg
# ./LSTM_PIC/headup/1/F (12).jpg
# ./LSTM_PIC/headup/1/F (13).jpg
# ./LSTM_PIC/headup/1/F (14).jpg
# ./LSTM_PIC/headup/1/F (15).jpg
# ./LSTM_PIC/headup/1/F (16).jpg
# ./LSTM_PIC/headup/1/F (17).jpg
# ./LSTM_PIC/headup/1/F (18).jpg
# ./LSTM_PIC/headup/1/F (19).jpg
# ./LSTM_PIC/headup/1/F (2).jpg
# ./LSTM_PIC/headup/1/F (20).jpg
# ./LSTM_PIC/headup/1/F (21).jpg
# ./LSTM_PIC/headup/1/F (22).jpg
# ./LSTM_PIC/headup/1/F (23).jpg
# ./LSTM_PIC/headup/1/F (24).jpg
# ./LSTM_PIC/headup/1/F (25).jpg
# ./LSTM_PIC/headup/1/F (26).jpg
# ./LSTM_PIC/headup/1/F (27).jpg
# ./LSTM_PIC/headup/1/F (28).jpg
# ./LSTM_PIC/headup/1/F (29).jpg
# ./LSTM_PIC/headup/1/F (3).jpg
# ./LSTM_PIC/headup/1/F (30).jpg
# ./LSTM_PIC/headup/1/F (4).jpg
# ./LSTM_PIC/headup/1/F (5).jpg
# ./LSTM_PIC/headup/1/F (6).jpg
# ./LSTM_PIC/headup/1/F (7).jpg
# ./LSTM_PIC/headup/1/F (8).jpg
# ./LSTM_PIC/headup/1/F (9).jpg
# ./LSTM_PIC/headup/2/A (1).jpg
# ./LSTM_PIC/headup/2/A (10).jpg
# ./LSTM_PIC/headup/2/A (11).jpg
# ./LSTM_PIC/headup/2/A (12).jpg
# ./LSTM_PIC/headup/2/A (13).jpg
# ./LSTM_PIC/headup/2/A (14).jpg
# ./LSTM_PIC/headup/2/A (15).jpg
# ./LSTM_PIC/headup/2/A (16).jpg
# ./LSTM_PIC/headup/2/A (17).jpg
# ./LSTM_PIC/headup/2/A (18).jpg
# ./LSTM_PIC/headup/2/A (19).jpg
# ./LSTM_PIC/headup/2/A (2).jpg
# ./LSTM_PIC/headup/2/A (20).jpg
# ./LSTM_PIC/headup/2/A (21).jpg
# ./LSTM_PIC/headup/2/A (22).jpg
# ./LSTM_PIC/headup/2/A (23).jpg
# ./LSTM_PIC/headup/2/A (24).jpg
# ./LSTM_PIC/headup/2/A (25).jpg
# ./LSTM_PIC/headup/2/A (26).jpg
# ./LSTM_PIC/headup/2/A (27).jpg
# ./LSTM_PIC/headup/2/A (28).jpg
# ./LSTM_PIC/headup/2/A (29).jpg
# ./LSTM_PIC/headup/2/A (3).jpg
# ./LSTM_PIC/headup/2/A (30).jpg
# ./LSTM_PIC/headup/2/A (4).jpg
# ./LSTM_PIC/headup/2/A (5).jpg
# ./LSTM_PIC/headup/2/A (6).jpg
# ./LSTM_PIC/headup/2/A (7).jpg
# ./LSTM_PIC/headup/2/A (8).jpg
# ./LSTM_PIC/headup/2/A (9).jpg
# ./LSTM_PIC/headup/3/A (1).jpg
# ./LSTM_PIC/headup/3/A (10).jpg
# ./LSTM_PIC/headup/3/A (11).jpg
# ./LSTM_PIC/headup/3/A (12).jpg
# ./LSTM_PIC/headup/3/A (13).jpg
# ./LSTM_PIC/headup/3/A (14).jpg
# ./LSTM_PIC/headup/3/A (15).jpg
# ./LSTM_PIC/headup/3/A (16).jpg
# ./LSTM_PIC/headup/3/A (17).jpg
# ./LSTM_PIC/headup/3/A (18).jpg
# ./LSTM_PIC/headup/3/A (19).jpg
# ./LSTM_PIC/headup/3/A (2).jpg
# ./LSTM_PIC/headup/3/A (20).jpg
# ./LSTM_PIC/headup/3/A (21).jpg
# ./LSTM_PIC/headup/3/A (22).jpg
# ./LSTM_PIC/headup/3/A (23).jpg
# ./LSTM_PIC/headup/3/A (24).jpg
# ./LSTM_PIC/headup/3/A (25).jpg
# ./LSTM_PIC/headup/3/A (26).jpg
# ./LSTM_PIC/headup/3/A (27).jpg
# ./LSTM_PIC/headup/3/A (28).jpg
# ./LSTM_PIC/headup/3/A (29).jpg
# ./LSTM_PIC/headup/3/A (3).jpg
# ./LSTM_PIC/headup/3/A (30).jpg
# ./LSTM_PIC/headup/3/A (4).jpg
# ./LSTM_PIC/headup/3/A (5).jpg
# ./LSTM_PIC/headup/3/A (6).jpg
# ./LSTM_PIC/headup/3/A (7).jpg
# ./LSTM_PIC/headup/3/A (8).jpg
# ./LSTM_PIC/headup/3/A (9).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000003.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000004.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000005.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - (2).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - (3).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - (4).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - (5).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - (6).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006 - .jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000006.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000007.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000008.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000009.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000010.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000011.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000012.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000013 - (2).jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000013 - a.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000013.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000014.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000015.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000016.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000017.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000018.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000019.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000020.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000021.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000022.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000023.jpg
# ./LSTM_PIC/headup/4/477-1-2-21-Z115_A-0000024.jpg
# ./LSTM_PIC/headup/5/B (1).jpg
# ./LSTM_PIC/headup/5/B (10).jpg
# ./LSTM_PIC/headup/5/B (11).jpg
# ./LSTM_PIC/headup/5/B (12).jpg
# ./LSTM_PIC/headup/5/B (13).jpg
# ./LSTM_PIC/headup/5/B (14).jpg
# ./LSTM_PIC/headup/5/B (15).jpg
# ./LSTM_PIC/headup/5/B (16).jpg
# ./LSTM_PIC/headup/5/B (17).jpg
# ./LSTM_PIC/headup/5/B (18).jpg
# ./LSTM_PIC/headup/5/B (19).jpg
# ./LSTM_PIC/headup/5/B (2).jpg
# ./LSTM_PIC/headup/5/B (20).jpg
# ./LSTM_PIC/headup/5/B (21).jpg
# ./LSTM_PIC/headup/5/B (22).jpg
# ./LSTM_PIC/headup/5/B (23).jpg
# ./LSTM_PIC/headup/5/B (24).jpg
# ./LSTM_PIC/headup/5/B (25).jpg
# ./LSTM_PIC/headup/5/B (26).jpg
# ./LSTM_PIC/headup/5/B (27).jpg
# ./LSTM_PIC/headup/5/B (28).jpg
# ./LSTM_PIC/headup/5/B (29).jpg
# ./LSTM_PIC/headup/5/B (3).jpg
# ./LSTM_PIC/headup/5/B (30).jpg
# ./LSTM_PIC/headup/5/B (4).jpg
# ./LSTM_PIC/headup/5/B (5).jpg
# ./LSTM_PIC/headup/5/B (6).jpg
# ./LSTM_PIC/headup/5/B (7).jpg
# ./LSTM_PIC/headup/5/B (8).jpg
# ./LSTM_PIC/headup/5/B (9).jpg
# ./LSTM_PIC/headup/6/A (1).jpg
# ./LSTM_PIC/headup/6/A (10).jpg
# ./LSTM_PIC/headup/6/A (11).jpg
# ./LSTM_PIC/headup/6/A (12).jpg
# ./LSTM_PIC/headup/6/A (13).jpg
# ./LSTM_PIC/headup/6/A (14).jpg
# ./LSTM_PIC/headup/6/A (15).jpg
# ./LSTM_PIC/headup/6/A (16).jpg
# ./LSTM_PIC/headup/6/A (17).jpg
# ./LSTM_PIC/headup/6/A (18).jpg
# ./LSTM_PIC/headup/6/A (19).jpg
# ./LSTM_PIC/headup/6/A (2).jpg
# ./LSTM_PIC/headup/6/A (20).jpg
# ./LSTM_PIC/headup/6/A (21).jpg
# ./LSTM_PIC/headup/6/A (22).jpg
# ./LSTM_PIC/headup/6/A (23).jpg
# ./LSTM_PIC/headup/6/A (24).jpg
# ./LSTM_PIC/headup/6/A (25).jpg
# ./LSTM_PIC/headup/6/A (26).jpg
# ./LSTM_PIC/headup/6/A (27).jpg
# ./LSTM_PIC/headup/6/A (28).jpg
# ./LSTM_PIC/headup/6/A (29).jpg
# ./LSTM_PIC/headup/6/A (3).jpg
# ./LSTM_PIC/headup/6/A (30).jpg
# ./LSTM_PIC/headup/6/A (4).jpg
# ./LSTM_PIC/headup/6/A (5).jpg
# ./LSTM_PIC/headup/6/A (6).jpg
# ./LSTM_PIC/headup/6/A (7).jpg
# ./LSTM_PIC/headup/6/A (8).jpg
# ./LSTM_PIC/headup/6/A (9).jpg
# ./LSTM_PIC/headup/7/A (1).jpg
# ./LSTM_PIC/headup/7/A (10).jpg
# ./LSTM_PIC/headup/7/A (11).jpg
# ./LSTM_PIC/headup/7/A (12).jpg
# ./LSTM_PIC/headup/7/A (13).jpg
# ./LSTM_PIC/headup/7/A (14).jpg
# ./LSTM_PIC/headup/7/A (15).jpg
# ./LSTM_PIC/headup/7/A (16).jpg
# ./LSTM_PIC/headup/7/A (17).jpg
# ./LSTM_PIC/headup/7/A (18).jpg
# ./LSTM_PIC/headup/7/A (19).jpg
# ./LSTM_PIC/headup/7/A (2).jpg
# ./LSTM_PIC/headup/7/A (20).jpg
# ./LSTM_PIC/headup/7/A (21).jpg
# ./LSTM_PIC/headup/7/A (22).jpg
# ./LSTM_PIC/headup/7/A (23).jpg
# ./LSTM_PIC/headup/7/A (24).jpg
# ./LSTM_PIC/headup/7/A (25).jpg
# ./LSTM_PIC/headup/7/A (26).jpg
# ./LSTM_PIC/headup/7/A (27).jpg
# ./LSTM_PIC/headup/7/A (28).jpg
# ./LSTM_PIC/headup/7/A (29).jpg
# ./LSTM_PIC/headup/7/A (3).jpg
# ./LSTM_PIC/headup/7/A (30).jpg
# ./LSTM_PIC/headup/7/A (4).jpg
# ./LSTM_PIC/headup/7/A (5).jpg
# ./LSTM_PIC/headup/7/A (6).jpg
# ./LSTM_PIC/headup/7/A (7).jpg
# ./LSTM_PIC/headup/7/A (8).jpg
# ./LSTM_PIC/headup/7/A (9).jpg
# ./LSTM_PIC/headup/8/A (1).jpg
# ./LSTM_PIC/headup/8/A (10).jpg
# ./LSTM_PIC/headup/8/A (11).jpg
# ./LSTM_PIC/headup/8/A (12).jpg
# ./LSTM_PIC/headup/8/A (13).jpg
# ./LSTM_PIC/headup/8/A (14).jpg
# ./LSTM_PIC/headup/8/A (15).jpg
# ./LSTM_PIC/headup/8/A (16).jpg
# ./LSTM_PIC/headup/8/A (17).jpg
# ./LSTM_PIC/headup/8/A (18).jpg
# ./LSTM_PIC/headup/8/A (19).jpg
# ./LSTM_PIC/headup/8/A (2).jpg
# ./LSTM_PIC/headup/8/A (20).jpg
# ./LSTM_PIC/headup/8/A (21).jpg
# ./LSTM_PIC/headup/8/A (22).jpg
# ./LSTM_PIC/headup/8/A (23).jpg
# ./LSTM_PIC/headup/8/A (24).jpg
# ./LSTM_PIC/headup/8/A (25).jpg
# ./LSTM_PIC/headup/8/A (26).jpg
# ./LSTM_PIC/headup/8/A (27).jpg
# ./LSTM_PIC/headup/8/A (28).jpg
# ./LSTM_PIC/headup/8/A (29).jpg
# ./LSTM_PIC/headup/8/A (3).jpg
# ./LSTM_PIC/headup/8/A (30).jpg
# ./LSTM_PIC/headup/8/A (4).jpg
# ./LSTM_PIC/headup/8/A (5).jpg
# ./LSTM_PIC/headup/8/A (6).jpg
# ./LSTM_PIC/headup/8/A (7).jpg
# ./LSTM_PIC/headup/8/A (8).jpg
# ./LSTM_PIC/headup/8/A (9).jpg
# ./LSTM_PIC/headup/9/A (1).jpg
# ./LSTM_PIC/headup/9/A (10).jpg
# ./LSTM_PIC/headup/9/A (11).jpg
# ./LSTM_PIC/headup/9/A (12).jpg
# ./LSTM_PIC/headup/9/A (13).jpg
# ./LSTM_PIC/headup/9/A (14).jpg
# ./LSTM_PIC/headup/9/A (15).jpg
# ./LSTM_PIC/headup/9/A (16).jpg
# ./LSTM_PIC/headup/9/A (17).jpg
# ./LSTM_PIC/headup/9/A (18).jpg
# ./LSTM_PIC/headup/9/A (19).jpg
# ./LSTM_PIC/headup/9/A (2).jpg
# ./LSTM_PIC/headup/9/A (20).jpg
# ./LSTM_PIC/headup/9/A (21).jpg
# ./LSTM_PIC/headup/9/A (22).jpg
# ./LSTM_PIC/headup/9/A (23).jpg
# ./LSTM_PIC/headup/9/A (24).jpg
# ./LSTM_PIC/headup/9/A (25).jpg
# ./LSTM_PIC/headup/9/A (26).jpg
# ./LSTM_PIC/headup/9/A (27).jpg
# ./LSTM_PIC/headup/9/A (28).jpg
# ./LSTM_PIC/headup/9/A (29).jpg
# ./LSTM_PIC/headup/9/A (3).jpg
# ./LSTM_PIC/headup/9/A (30).jpg
# ./LSTM_PIC/headup/9/A (4).jpg
# ./LSTM_PIC/headup/9/A (5).jpg
# ./LSTM_PIC/headup/9/A (6).jpg
# ./LSTM_PIC/headup/9/A (7).jpg
# ./LSTM_PIC/headup/9/A (8).jpg
# ./LSTM_PIC/headup/9/A (9).jpg
# ./LSTM_PIC/right/0/A (1).jpg
# ./LSTM_PIC/right/0/A (10).jpg
# ./LSTM_PIC/right/0/A (11).jpg
# ./LSTM_PIC/right/0/A (12).jpg
# ./LSTM_PIC/right/0/A (13).jpg
# ./LSTM_PIC/right/0/A (14).jpg
# ./LSTM_PIC/right/0/A (15).jpg
# ./LSTM_PIC/right/0/A (16).jpg
# ./LSTM_PIC/right/0/A (17).jpg
# ./LSTM_PIC/right/0/A (18).jpg
# ./LSTM_PIC/right/0/A (19).jpg
# ./LSTM_PIC/right/0/A (2).jpg
# ./LSTM_PIC/right/0/A (20).jpg
# ./LSTM_PIC/right/0/A (21).jpg
# ./LSTM_PIC/right/0/A (22).jpg
# ./LSTM_PIC/right/0/A (23).jpg
# ./LSTM_PIC/right/0/A (24).jpg
# ./LSTM_PIC/right/0/A (25).jpg
# ./LSTM_PIC/right/0/A (26).jpg
# ./LSTM_PIC/right/0/A (27).jpg
# ./LSTM_PIC/right/0/A (28).jpg
# ./LSTM_PIC/right/0/A (29).jpg
# ./LSTM_PIC/right/0/A (3).jpg
# ./LSTM_PIC/right/0/A (30).jpg
# ./LSTM_PIC/right/0/A (4).jpg
# ./LSTM_PIC/right/0/A (5).jpg
# ./LSTM_PIC/right/0/A (6).jpg
# ./LSTM_PIC/right/0/A (7).jpg
# ./LSTM_PIC/right/0/A (8).jpg
# ./LSTM_PIC/right/0/A (9).jpg
# ./LSTM_PIC/right/1/V (1).jpg
# ./LSTM_PIC/right/1/V (10).jpg
# ./LSTM_PIC/right/1/V (11).jpg
# ./LSTM_PIC/right/1/V (12).jpg
# ./LSTM_PIC/right/1/V (13).jpg
# ./LSTM_PIC/right/1/V (14).jpg
# ./LSTM_PIC/right/1/V (15).jpg
# ./LSTM_PIC/right/1/V (16).jpg
# ./LSTM_PIC/right/1/V (17).jpg
# ./LSTM_PIC/right/1/V (18).jpg
# ./LSTM_PIC/right/1/V (19).jpg
# ./LSTM_PIC/right/1/V (2).jpg
# ./LSTM_PIC/right/1/V (20).jpg
# ./LSTM_PIC/right/1/V (21).jpg
# ./LSTM_PIC/right/1/V (22).jpg
# ./LSTM_PIC/right/1/V (23).jpg
# ./LSTM_PIC/right/1/V (24).jpg
# ./LSTM_PIC/right/1/V (25).jpg
# ./LSTM_PIC/right/1/V (26).jpg
# ./LSTM_PIC/right/1/V (27).jpg
# ./LSTM_PIC/right/1/V (28).jpg
# ./LSTM_PIC/right/1/V (29).jpg
# ./LSTM_PIC/right/1/V (3).jpg
# ./LSTM_PIC/right/1/V (30).jpg
# ./LSTM_PIC/right/1/V (4).jpg
# ./LSTM_PIC/right/1/V (5).jpg
# ./LSTM_PIC/right/1/V (6).jpg
# ./LSTM_PIC/right/1/V (7).jpg
# ./LSTM_PIC/right/1/V (8).jpg
# ./LSTM_PIC/right/1/V (9).jpg
# ./LSTM_PIC/right/2/P (1).jpg
# ./LSTM_PIC/right/2/P (10).jpg
# ./LSTM_PIC/right/2/P (11).jpg
# ./LSTM_PIC/right/2/P (12).jpg
# ./LSTM_PIC/right/2/P (13).jpg
# ./LSTM_PIC/right/2/P (14).jpg
# ./LSTM_PIC/right/2/P (15).jpg
# ./LSTM_PIC/right/2/P (16).jpg
# ./LSTM_PIC/right/2/P (17).jpg
# ./LSTM_PIC/right/2/P (18).jpg
# ./LSTM_PIC/right/2/P (19).jpg
# ./LSTM_PIC/right/2/P (2).jpg
# ./LSTM_PIC/right/2/P (20).jpg
# ./LSTM_PIC/right/2/P (21).jpg
# ./LSTM_PIC/right/2/P (22).jpg
# ./LSTM_PIC/right/2/P (23).jpg
# ./LSTM_PIC/right/2/P (24).jpg
# ./LSTM_PIC/right/2/P (25).jpg
# ./LSTM_PIC/right/2/P (26).jpg
# ./LSTM_PIC/right/2/P (27).jpg
# ./LSTM_PIC/right/2/P (28).jpg
# ./LSTM_PIC/right/2/P (29).jpg
# ./LSTM_PIC/right/2/P (3).jpg
# ./LSTM_PIC/right/2/P (30).jpg
# ./LSTM_PIC/right/2/P (4).jpg
# ./LSTM_PIC/right/2/P (5).jpg
# ./LSTM_PIC/right/2/P (6).jpg
# ./LSTM_PIC/right/2/P (7).jpg
# ./LSTM_PIC/right/2/P (8).jpg
# ./LSTM_PIC/right/2/P (9).jpg
# ./LSTM_PIC/right/3/U (1).jpg
# ./LSTM_PIC/right/3/U (10).jpg
# ./LSTM_PIC/right/3/U (11).jpg
# ./LSTM_PIC/right/3/U (12).jpg
# ./LSTM_PIC/right/3/U (13).jpg
# ./LSTM_PIC/right/3/U (14).jpg
# ./LSTM_PIC/right/3/U (15).jpg
# ./LSTM_PIC/right/3/U (16).jpg
# ./LSTM_PIC/right/3/U (17).jpg
# ./LSTM_PIC/right/3/U (18).jpg
# ./LSTM_PIC/right/3/U (19).jpg
# ./LSTM_PIC/right/3/U (2).jpg
# ./LSTM_PIC/right/3/U (20).jpg
# ./LSTM_PIC/right/3/U (21).jpg
# ./LSTM_PIC/right/3/U (22).jpg
# ./LSTM_PIC/right/3/U (23).jpg
# ./LSTM_PIC/right/3/U (24).jpg
# ./LSTM_PIC/right/3/U (25).jpg
# ./LSTM_PIC/right/3/U (26).jpg
# ./LSTM_PIC/right/3/U (27).jpg
# ./LSTM_PIC/right/3/U (28).jpg
# ./LSTM_PIC/right/3/U (29).jpg
# ./LSTM_PIC/right/3/U (3).jpg
# ./LSTM_PIC/right/3/U (30).jpg
# ./LSTM_PIC/right/3/U (4).jpg
# ./LSTM_PIC/right/3/U (5).jpg
# ./LSTM_PIC/right/3/U (6).jpg
# ./LSTM_PIC/right/3/U (7).jpg
# ./LSTM_PIC/right/3/U (8).jpg
# ./LSTM_PIC/right/3/U (9).jpg
# ./LSTM_PIC/right/4/T-1 (1).jpg
# ./LSTM_PIC/right/4/T-1 (10).jpg
# ./LSTM_PIC/right/4/T-1 (11).jpg
# ./LSTM_PIC/right/4/T-1 (12).jpg
# ./LSTM_PIC/right/4/T-1 (13).jpg
# ./LSTM_PIC/right/4/T-1 (14).jpg
# ./LSTM_PIC/right/4/T-1 (15).jpg
# ./LSTM_PIC/right/4/T-1 (16).jpg
# ./LSTM_PIC/right/4/T-1 (17).jpg
# ./LSTM_PIC/right/4/T-1 (18).jpg
# ./LSTM_PIC/right/4/T-1 (19).jpg
# ./LSTM_PIC/right/4/T-1 (2).jpg
# ./LSTM_PIC/right/4/T-1 (20).jpg
# ./LSTM_PIC/right/4/T-1 (21).jpg
# ./LSTM_PIC/right/4/T-1 (22).jpg
# ./LSTM_PIC/right/4/T-1 (23).jpg
# ./LSTM_PIC/right/4/T-1 (24).jpg
# ./LSTM_PIC/right/4/T-1 (25).jpg
# ./LSTM_PIC/right/4/T-1 (26).jpg
# ./LSTM_PIC/right/4/T-1 (27).jpg
# ./LSTM_PIC/right/4/T-1 (28).jpg
# ./LSTM_PIC/right/4/T-1 (29).jpg
# ./LSTM_PIC/right/4/T-1 (3).jpg
# ./LSTM_PIC/right/4/T-1 (30).jpg
# ./LSTM_PIC/right/4/T-1 (4).jpg
# ./LSTM_PIC/right/4/T-1 (5).jpg
# ./LSTM_PIC/right/4/T-1 (6).jpg
# ./LSTM_PIC/right/4/T-1 (7).jpg
# ./LSTM_PIC/right/4/T-1 (8).jpg
# ./LSTM_PIC/right/4/T-1 (9).jpg
# ./LSTM_PIC/right/5/D (1).jpg
# ./LSTM_PIC/right/5/D (10).jpg
# ./LSTM_PIC/right/5/D (11).jpg
# ./LSTM_PIC/right/5/D (12).jpg
# ./LSTM_PIC/right/5/D (13).jpg
# ./LSTM_PIC/right/5/D (14).jpg
# ./LSTM_PIC/right/5/D (15).jpg
# ./LSTM_PIC/right/5/D (16).jpg
# ./LSTM_PIC/right/5/D (17).jpg
# ./LSTM_PIC/right/5/D (18).jpg
# ./LSTM_PIC/right/5/D (19).jpg
# ./LSTM_PIC/right/5/D (2).jpg
# ./LSTM_PIC/right/5/D (20).jpg
# ./LSTM_PIC/right/5/D (21).jpg
# ./LSTM_PIC/right/5/D (22).jpg
# ./LSTM_PIC/right/5/D (23).jpg
# ./LSTM_PIC/right/5/D (24).jpg
# ./LSTM_PIC/right/5/D (25).jpg
# ./LSTM_PIC/right/5/D (26).jpg
# ./LSTM_PIC/right/5/D (27).jpg
# ./LSTM_PIC/right/5/D (28).jpg
# ./LSTM_PIC/right/5/D (29).jpg
# ./LSTM_PIC/right/5/D (3).jpg
# ./LSTM_PIC/right/5/D (30).jpg
# ./LSTM_PIC/right/5/D (4).jpg
# ./LSTM_PIC/right/5/D (5).jpg
# ./LSTM_PIC/right/5/D (6).jpg
# ./LSTM_PIC/right/5/D (7).jpg
# ./LSTM_PIC/right/5/D (8).jpg
# ./LSTM_PIC/right/5/D (9).jpg
# ./LSTM_PIC/right/6/E (1).jpg
# ./LSTM_PIC/right/6/E (10).jpg
# ./LSTM_PIC/right/6/E (11).jpg
# ./LSTM_PIC/right/6/E (12).jpg
# ./LSTM_PIC/right/6/E (13).jpg
# ./LSTM_PIC/right/6/E (14).jpg
# ./LSTM_PIC/right/6/E (15).jpg
# ./LSTM_PIC/right/6/E (16).jpg
# ./LSTM_PIC/right/6/E (17).jpg
# ./LSTM_PIC/right/6/E (18).jpg
# ./LSTM_PIC/right/6/E (19).jpg
# ./LSTM_PIC/right/6/E (2).jpg
# ./LSTM_PIC/right/6/E (20).jpg
# ./LSTM_PIC/right/6/E (21).jpg
# ./LSTM_PIC/right/6/E (22).jpg
# ./LSTM_PIC/right/6/E (23).jpg
# ./LSTM_PIC/right/6/E (24).jpg
# ./LSTM_PIC/right/6/E (25).jpg
# ./LSTM_PIC/right/6/E (26).jpg
# ./LSTM_PIC/right/6/E (27).jpg
# ./LSTM_PIC/right/6/E (28).jpg
# ./LSTM_PIC/right/6/E (29).jpg
# ./LSTM_PIC/right/6/E (3).jpg
# ./LSTM_PIC/right/6/E (30).jpg
# ./LSTM_PIC/right/6/E (4).jpg
# ./LSTM_PIC/right/6/E (5).jpg
# ./LSTM_PIC/right/6/E (6).jpg
# ./LSTM_PIC/right/6/E (7).jpg
# ./LSTM_PIC/right/6/E (8).jpg
# ./LSTM_PIC/right/6/E (9).jpg
# ./LSTM_PIC/right/7/G (1).jpg
# ./LSTM_PIC/right/7/G (10).jpg
# ./LSTM_PIC/right/7/G (11).jpg
# ./LSTM_PIC/right/7/G (12).jpg
# ./LSTM_PIC/right/7/G (13).jpg
# ./LSTM_PIC/right/7/G (14).jpg
# ./LSTM_PIC/right/7/G (15).jpg
# ./LSTM_PIC/right/7/G (16).jpg
# ./LSTM_PIC/right/7/G (17).jpg
# ./LSTM_PIC/right/7/G (18).jpg
# ./LSTM_PIC/right/7/G (19).jpg
# ./LSTM_PIC/right/7/G (2).jpg
# ./LSTM_PIC/right/7/G (20).jpg
# ./LSTM_PIC/right/7/G (21).jpg
# ./LSTM_PIC/right/7/G (22).jpg
# ./LSTM_PIC/right/7/G (23).jpg
# ./LSTM_PIC/right/7/G (24).jpg
# ./LSTM_PIC/right/7/G (25).jpg
# ./LSTM_PIC/right/7/G (26).jpg
# ./LSTM_PIC/right/7/G (27).jpg
# ./LSTM_PIC/right/7/G (28).jpg
# ./LSTM_PIC/right/7/G (29).jpg
# ./LSTM_PIC/right/7/G (3).jpg
# ./LSTM_PIC/right/7/G (30).jpg
# ./LSTM_PIC/right/7/G (4).jpg
# ./LSTM_PIC/right/7/G (5).jpg
# ./LSTM_PIC/right/7/G (6).jpg
# ./LSTM_PIC/right/7/G (7).jpg
# ./LSTM_PIC/right/7/G (8).jpg
# ./LSTM_PIC/right/7/G (9).jpg
# ./LSTM_PIC/right/8/S-1 (1).jpg
# ./LSTM_PIC/right/8/S-1 (10).jpg
# ./LSTM_PIC/right/8/S-1 (11).jpg
# ./LSTM_PIC/right/8/S-1 (12).jpg
# ./LSTM_PIC/right/8/S-1 (13).jpg
# ./LSTM_PIC/right/8/S-1 (14).jpg
# ./LSTM_PIC/right/8/S-1 (15).jpg
# ./LSTM_PIC/right/8/S-1 (16).jpg
# ./LSTM_PIC/right/8/S-1 (17).jpg
# ./LSTM_PIC/right/8/S-1 (18).jpg
# ./LSTM_PIC/right/8/S-1 (19).jpg
# ./LSTM_PIC/right/8/S-1 (2).jpg
# ./LSTM_PIC/right/8/S-1 (20).jpg
# ./LSTM_PIC/right/8/S-1 (21).jpg
# ./LSTM_PIC/right/8/S-1 (22).jpg
# ./LSTM_PIC/right/8/S-1 (23).jpg
# ./LSTM_PIC/right/8/S-1 (24).jpg
# ./LSTM_PIC/right/8/S-1 (25).jpg
# ./LSTM_PIC/right/8/S-1 (26).jpg
# ./LSTM_PIC/right/8/S-1 (27).jpg
# ./LSTM_PIC/right/8/S-1 (28).jpg
# ./LSTM_PIC/right/8/S-1 (29).jpg
# ./LSTM_PIC/right/8/S-1 (3).jpg
# ./LSTM_PIC/right/8/S-1 (30).jpg
# ./LSTM_PIC/right/8/S-1 (4).jpg
# ./LSTM_PIC/right/8/S-1 (5).jpg
# ./LSTM_PIC/right/8/S-1 (6).jpg
# ./LSTM_PIC/right/8/S-1 (7).jpg
# ./LSTM_PIC/right/8/S-1 (8).jpg
# ./LSTM_PIC/right/8/S-1 (9).jpg
# ./LSTM_PIC/right/9/K (1).jpg
# ./LSTM_PIC/right/9/K (10).jpg
# ./LSTM_PIC/right/9/K (11).jpg
# ./LSTM_PIC/right/9/K (12).jpg
# ./LSTM_PIC/right/9/K (13).jpg
# ./LSTM_PIC/right/9/K (14).jpg
# ./LSTM_PIC/right/9/K (15).jpg
# ./LSTM_PIC/right/9/K (16).jpg
# ./LSTM_PIC/right/9/K (17).jpg
# ./LSTM_PIC/right/9/K (18).jpg
# ./LSTM_PIC/right/9/K (19).jpg
# ./LSTM_PIC/right/9/K (2).jpg
# ./LSTM_PIC/right/9/K (20).jpg
# ./LSTM_PIC/right/9/K (21).jpg
# ./LSTM_PIC/right/9/K (22).jpg
# ./LSTM_PIC/right/9/K (23).jpg
# ./LSTM_PIC/right/9/K (24).jpg
# ./LSTM_PIC/right/9/K (25).jpg
# ./LSTM_PIC/right/9/K (26).jpg
# ./LSTM_PIC/right/9/K (27).jpg
# ./LSTM_PIC/right/9/K (28).jpg
# ./LSTM_PIC/right/9/K (29).jpg
# ./LSTM_PIC/right/9/K (3).jpg
# ./LSTM_PIC/right/9/K (30).jpg
# ./LSTM_PIC/right/9/K (4).jpg
# ./LSTM_PIC/right/9/K (5).jpg
# ./LSTM_PIC/right/9/K (6).jpg
# ./LSTM_PIC/right/9/K (7).jpg
# ./LSTM_PIC/right/9/K (8).jpg
# ./LSTM_PIC/right/9/K (9).jpg
# ./LSTM_PIC/waistup/0/A (1).jpg
# ./LSTM_PIC/waistup/0/A (10).jpg
# ./LSTM_PIC/waistup/0/A (11).jpg
# ./LSTM_PIC/waistup/0/A (12).jpg
# ./LSTM_PIC/waistup/0/A (13).jpg
# ./LSTM_PIC/waistup/0/A (14).jpg
# ./LSTM_PIC/waistup/0/A (15).jpg
# ./LSTM_PIC/waistup/0/A (16).jpg
# ./LSTM_PIC/waistup/0/A (17).jpg
# ./LSTM_PIC/waistup/0/A (18).jpg
# ./LSTM_PIC/waistup/0/A (19).jpg
# ./LSTM_PIC/waistup/0/A (2).jpg
# ./LSTM_PIC/waistup/0/A (20).jpg
# ./LSTM_PIC/waistup/0/A (21).jpg
# ./LSTM_PIC/waistup/0/A (22).jpg
# ./LSTM_PIC/waistup/0/A (23).jpg
# ./LSTM_PIC/waistup/0/A (24).jpg
# ./LSTM_PIC/waistup/0/A (25).jpg
# ./LSTM_PIC/waistup/0/A (26).jpg
# ./LSTM_PIC/waistup/0/A (27).jpg
# ./LSTM_PIC/waistup/0/A (28).jpg
# ./LSTM_PIC/waistup/0/A (29).jpg
# ./LSTM_PIC/waistup/0/A (3).jpg
# ./LSTM_PIC/waistup/0/A (30).jpg
# ./LSTM_PIC/waistup/0/A (4).jpg
# ./LSTM_PIC/waistup/0/A (5).jpg
# ./LSTM_PIC/waistup/0/A (6).jpg
# ./LSTM_PIC/waistup/0/A (7).jpg
# ./LSTM_PIC/waistup/0/A (8).jpg
# ./LSTM_PIC/waistup/0/A (9).jpg
# ./LSTM_PIC/waistup/1/Z (1).jpg
# ./LSTM_PIC/waistup/1/Z (10).jpg
# ./LSTM_PIC/waistup/1/Z (11).jpg
# ./LSTM_PIC/waistup/1/Z (12).jpg
# ./LSTM_PIC/waistup/1/Z (13).jpg
# ./LSTM_PIC/waistup/1/Z (14).jpg
# ./LSTM_PIC/waistup/1/Z (15).jpg
# ./LSTM_PIC/waistup/1/Z (16).jpg
# ./LSTM_PIC/waistup/1/Z (17).jpg
# ./LSTM_PIC/waistup/1/Z (18).jpg
# ./LSTM_PIC/waistup/1/Z (19).jpg
# ./LSTM_PIC/waistup/1/Z (2).jpg
# ./LSTM_PIC/waistup/1/Z (20).jpg
# ./LSTM_PIC/waistup/1/Z (21).jpg
# ./LSTM_PIC/waistup/1/Z (22).jpg
# ./LSTM_PIC/waistup/1/Z (23).jpg
# ./LSTM_PIC/waistup/1/Z (24).jpg
# ./LSTM_PIC/waistup/1/Z (25).jpg
# ./LSTM_PIC/waistup/1/Z (26).jpg
# ./LSTM_PIC/waistup/1/Z (27).jpg
# ./LSTM_PIC/waistup/1/Z (28).jpg
# ./LSTM_PIC/waistup/1/Z (29).jpg
# ./LSTM_PIC/waistup/1/Z (3).jpg
# ./LSTM_PIC/waistup/1/Z (30).jpg
# ./LSTM_PIC/waistup/1/Z (4).jpg
# ./LSTM_PIC/waistup/1/Z (5).jpg
# ./LSTM_PIC/waistup/1/Z (6).jpg
# ./LSTM_PIC/waistup/1/Z (7).jpg
# ./LSTM_PIC/waistup/1/Z (8).jpg
# ./LSTM_PIC/waistup/1/Z (9).jpg
# ./LSTM_PIC/waistup/2/Y (1).jpg
# ./LSTM_PIC/waistup/2/Y (10).jpg
# ./LSTM_PIC/waistup/2/Y (11).jpg
# ./LSTM_PIC/waistup/2/Y (12).jpg
# ./LSTM_PIC/waistup/2/Y (13).jpg
# ./LSTM_PIC/waistup/2/Y (14).jpg
# ./LSTM_PIC/waistup/2/Y (15).jpg
# ./LSTM_PIC/waistup/2/Y (16).jpg
# ./LSTM_PIC/waistup/2/Y (17).jpg
# ./LSTM_PIC/waistup/2/Y (18).jpg
# ./LSTM_PIC/waistup/2/Y (19).jpg
# ./LSTM_PIC/waistup/2/Y (2).jpg
# ./LSTM_PIC/waistup/2/Y (20).jpg
# ./LSTM_PIC/waistup/2/Y (21).jpg
# ./LSTM_PIC/waistup/2/Y (22).jpg
# ./LSTM_PIC/waistup/2/Y (23).jpg
# ./LSTM_PIC/waistup/2/Y (24).jpg
# ./LSTM_PIC/waistup/2/Y (25).jpg
# ./LSTM_PIC/waistup/2/Y (26).jpg
# ./LSTM_PIC/waistup/2/Y (27).jpg
# ./LSTM_PIC/waistup/2/Y (28).jpg
# ./LSTM_PIC/waistup/2/Y (29).jpg
# ./LSTM_PIC/waistup/2/Y (3).jpg
# ./LSTM_PIC/waistup/2/Y (30).jpg
# ./LSTM_PIC/waistup/2/Y (4).jpg
# ./LSTM_PIC/waistup/2/Y (5).jpg
# ./LSTM_PIC/waistup/2/Y (6).jpg
# ./LSTM_PIC/waistup/2/Y (7).jpg
# ./LSTM_PIC/waistup/2/Y (8).jpg
# ./LSTM_PIC/waistup/2/Y (9).jpg
# ./LSTM_PIC/waistup/3/A (1).jpg
# ./LSTM_PIC/waistup/3/A (10).jpg
# ./LSTM_PIC/waistup/3/A (11).jpg
# ./LSTM_PIC/waistup/3/A (12).jpg
# ./LSTM_PIC/waistup/3/A (13).jpg
# ./LSTM_PIC/waistup/3/A (14).jpg
# ./LSTM_PIC/waistup/3/A (15).jpg
# ./LSTM_PIC/waistup/3/A (16).jpg
# ./LSTM_PIC/waistup/3/A (17).jpg
# ./LSTM_PIC/waistup/3/A (18).jpg
# ./LSTM_PIC/waistup/3/A (19).jpg
# ./LSTM_PIC/waistup/3/A (2).jpg
# ./LSTM_PIC/waistup/3/A (20).jpg
# ./LSTM_PIC/waistup/3/A (21).jpg
# ./LSTM_PIC/waistup/3/A (22).jpg
# ./LSTM_PIC/waistup/3/A (23).jpg
# ./LSTM_PIC/waistup/3/A (24).jpg
# ./LSTM_PIC/waistup/3/A (25).jpg
# ./LSTM_PIC/waistup/3/A (26).jpg
# ./LSTM_PIC/waistup/3/A (27).jpg
# ./LSTM_PIC/waistup/3/A (28).jpg
# ./LSTM_PIC/waistup/3/A (29).jpg
# ./LSTM_PIC/waistup/3/A (3).jpg
# ./LSTM_PIC/waistup/3/A (30).jpg
# ./LSTM_PIC/waistup/3/A (4).jpg
# ./LSTM_PIC/waistup/3/A (5).jpg
# ./LSTM_PIC/waistup/3/A (6).jpg
# ./LSTM_PIC/waistup/3/A (7).jpg
# ./LSTM_PIC/waistup/3/A (8).jpg
# ./LSTM_PIC/waistup/3/A (9).jpg
# ./LSTM_PIC/waistup/4/r (1).jpg
# ./LSTM_PIC/waistup/4/r (10).jpg
# ./LSTM_PIC/waistup/4/r (11).jpg
# ./LSTM_PIC/waistup/4/r (12).jpg
# ./LSTM_PIC/waistup/4/r (13).jpg
# ./LSTM_PIC/waistup/4/r (14).jpg
# ./LSTM_PIC/waistup/4/r (15).jpg
# ./LSTM_PIC/waistup/4/r (16).jpg
# ./LSTM_PIC/waistup/4/r (17).jpg
# ./LSTM_PIC/waistup/4/r (18).jpg
# ./LSTM_PIC/waistup/4/r (19).jpg
# ./LSTM_PIC/waistup/4/r (2).jpg
# ./LSTM_PIC/waistup/4/r (20).jpg
# ./LSTM_PIC/waistup/4/r (21).jpg
# ./LSTM_PIC/waistup/4/r (22).jpg
# ./LSTM_PIC/waistup/4/r (23).jpg
# ./LSTM_PIC/waistup/4/r (24).jpg
# ./LSTM_PIC/waistup/4/r (25).jpg
# ./LSTM_PIC/waistup/4/r (26).jpg
# ./LSTM_PIC/waistup/4/r (27).jpg
# ./LSTM_PIC/waistup/4/r (28).jpg
# ./LSTM_PIC/waistup/4/r (29).jpg
# ./LSTM_PIC/waistup/4/r (3).jpg
# ./LSTM_PIC/waistup/4/r (30).jpg
# ./LSTM_PIC/waistup/4/r (4).jpg
# ./LSTM_PIC/waistup/4/r (5).jpg
# ./LSTM_PIC/waistup/4/r (6).jpg
# ./LSTM_PIC/waistup/4/r (7).jpg
# ./LSTM_PIC/waistup/4/r (8).jpg
# ./LSTM_PIC/waistup/4/r (9).jpg
# ./LSTM_PIC/waistup/5/A (1).jpg
# ./LSTM_PIC/waistup/5/A (10).jpg
# ./LSTM_PIC/waistup/5/A (11).jpg
# ./LSTM_PIC/waistup/5/A (12).jpg
# ./LSTM_PIC/waistup/5/A (13).jpg
# ./LSTM_PIC/waistup/5/A (14).jpg
# ./LSTM_PIC/waistup/5/A (15).jpg
# ./LSTM_PIC/waistup/5/A (16).jpg
# ./LSTM_PIC/waistup/5/A (17).jpg
# ./LSTM_PIC/waistup/5/A (18).jpg
# ./LSTM_PIC/waistup/5/A (19).jpg
# ./LSTM_PIC/waistup/5/A (2).jpg
# ./LSTM_PIC/waistup/5/A (20).jpg
# ./LSTM_PIC/waistup/5/A (21).jpg
# ./LSTM_PIC/waistup/5/A (22).jpg
# ./LSTM_PIC/waistup/5/A (23).jpg
# ./LSTM_PIC/waistup/5/A (24).jpg
# ./LSTM_PIC/waistup/5/A (25).jpg
# ./LSTM_PIC/waistup/5/A (26).jpg
# ./LSTM_PIC/waistup/5/A (27).jpg
# ./LSTM_PIC/waistup/5/A (28).jpg
# ./LSTM_PIC/waistup/5/A (29).jpg
# ./LSTM_PIC/waistup/5/A (3).jpg
# ./LSTM_PIC/waistup/5/A (30).jpg
# ./LSTM_PIC/waistup/5/A (4).jpg
# ./LSTM_PIC/waistup/5/A (5).jpg
# ./LSTM_PIC/waistup/5/A (6).jpg
# ./LSTM_PIC/waistup/5/A (7).jpg
# ./LSTM_PIC/waistup/5/A (8).jpg
# ./LSTM_PIC/waistup/5/A (9).jpg
# ./LSTM_PIC/waistup/6/a (1).jpg
# ./LSTM_PIC/waistup/6/a (10).jpg
# ./LSTM_PIC/waistup/6/a (11).jpg
# ./LSTM_PIC/waistup/6/a (12).jpg
# ./LSTM_PIC/waistup/6/a (13).jpg
# ./LSTM_PIC/waistup/6/a (14).jpg
# ./LSTM_PIC/waistup/6/a (15).jpg
# ./LSTM_PIC/waistup/6/a (16).jpg
# ./LSTM_PIC/waistup/6/a (17).jpg
# ./LSTM_PIC/waistup/6/a (18).jpg
# ./LSTM_PIC/waistup/6/a (19).jpg
# ./LSTM_PIC/waistup/6/a (2).jpg
# ./LSTM_PIC/waistup/6/a (20).jpg
# ./LSTM_PIC/waistup/6/a (21).jpg
# ./LSTM_PIC/waistup/6/a (22).jpg
# ./LSTM_PIC/waistup/6/a (23).jpg
# ./LSTM_PIC/waistup/6/a (24).jpg
# ./LSTM_PIC/waistup/6/a (25).jpg
# ./LSTM_PIC/waistup/6/a (26).jpg
# ./LSTM_PIC/waistup/6/a (27).jpg
# ./LSTM_PIC/waistup/6/a (28).jpg
# ./LSTM_PIC/waistup/6/a (29).jpg
# ./LSTM_PIC/waistup/6/a (3).jpg
# ./LSTM_PIC/waistup/6/a (30).jpg
# ./LSTM_PIC/waistup/6/a (4).jpg
# ./LSTM_PIC/waistup/6/a (5).jpg
# ./LSTM_PIC/waistup/6/a (6).jpg
# ./LSTM_PIC/waistup/6/a (7).jpg
# ./LSTM_PIC/waistup/6/a (8).jpg
# ./LSTM_PIC/waistup/6/a (9).jpg
# ./LSTM_PIC/waistup/7/A (1).jpg
# ./LSTM_PIC/waistup/7/A (10).jpg
# ./LSTM_PIC/waistup/7/A (11).jpg
# ./LSTM_PIC/waistup/7/A (12).jpg
# ./LSTM_PIC/waistup/7/A (13).jpg
# ./LSTM_PIC/waistup/7/A (14).jpg
# ./LSTM_PIC/waistup/7/A (15).jpg
# ./LSTM_PIC/waistup/7/A (16).jpg
# ./LSTM_PIC/waistup/7/A (17).jpg
# ./LSTM_PIC/waistup/7/A (18).jpg
# ./LSTM_PIC/waistup/7/A (19).jpg
# ./LSTM_PIC/waistup/7/A (2).jpg
# ./LSTM_PIC/waistup/7/A (20).jpg
# ./LSTM_PIC/waistup/7/A (21).jpg
# ./LSTM_PIC/waistup/7/A (22).jpg
# ./LSTM_PIC/waistup/7/A (23).jpg
# ./LSTM_PIC/waistup/7/A (24).jpg
# ./LSTM_PIC/waistup/7/A (25).jpg
# ./LSTM_PIC/waistup/7/A (26).jpg
# ./LSTM_PIC/waistup/7/A (27).jpg
# ./LSTM_PIC/waistup/7/A (28).jpg
# ./LSTM_PIC/waistup/7/A (29).jpg
# ./LSTM_PIC/waistup/7/A (3).jpg
# ./LSTM_PIC/waistup/7/A (30).jpg
# ./LSTM_PIC/waistup/7/A (4).jpg
# ./LSTM_PIC/waistup/7/A (5).jpg
# ./LSTM_PIC/waistup/7/A (6).jpg
# ./LSTM_PIC/waistup/7/A (7).jpg
# ./LSTM_PIC/waistup/7/A (8).jpg
# ./LSTM_PIC/waistup/7/A (9).jpg
# ./LSTM_PIC/waistup/8/v (1).jpg
# ./LSTM_PIC/waistup/8/v (10).jpg
# ./LSTM_PIC/waistup/8/v (11).jpg
# ./LSTM_PIC/waistup/8/v (12).jpg
# ./LSTM_PIC/waistup/8/v (13).jpg
# ./LSTM_PIC/waistup/8/v (14).jpg
# ./LSTM_PIC/waistup/8/v (15).jpg
# ./LSTM_PIC/waistup/8/v (16).jpg
# ./LSTM_PIC/waistup/8/v (17).jpg
# ./LSTM_PIC/waistup/8/v (18).jpg
# ./LSTM_PIC/waistup/8/v (19).jpg
# ./LSTM_PIC/waistup/8/v (2).jpg
# ./LSTM_PIC/waistup/8/v (20).jpg
# ./LSTM_PIC/waistup/8/v (21).jpg
# ./LSTM_PIC/waistup/8/v (22).jpg
# ./LSTM_PIC/waistup/8/v (23).jpg
# ./LSTM_PIC/waistup/8/v (24).jpg
# ./LSTM_PIC/waistup/8/v (25).jpg
# ./LSTM_PIC/waistup/8/v (26).jpg
# ./LSTM_PIC/waistup/8/v (27).jpg
# ./LSTM_PIC/waistup/8/v (28).jpg
# ./LSTM_PIC/waistup/8/v (29).jpg
# ./LSTM_PIC/waistup/8/v (3).jpg
# ./LSTM_PIC/waistup/8/v (30).jpg
# ./LSTM_PIC/waistup/8/v (4).jpg
# ./LSTM_PIC/waistup/8/v (5).jpg
# ./LSTM_PIC/waistup/8/v (6).jpg
# ./LSTM_PIC/waistup/8/v (7).jpg
# ./LSTM_PIC/waistup/8/v (8).jpg
# ./LSTM_PIC/waistup/8/v (9).jpg
# ./LSTM_PIC/waistup/9/A (1).jpg
# ./LSTM_PIC/waistup/9/A (10).jpg
# ./LSTM_PIC/waistup/9/A (11).jpg
# ./LSTM_PIC/waistup/9/A (12).jpg
# ./LSTM_PIC/waistup/9/A (13).jpg
# ./LSTM_PIC/waistup/9/A (14).jpg
# ./LSTM_PIC/waistup/9/A (15).jpg
# ./LSTM_PIC/waistup/9/A (16).jpg
# ./LSTM_PIC/waistup/9/A (17).jpg
# ./LSTM_PIC/waistup/9/A (18).jpg
# ./LSTM_PIC/waistup/9/A (19).jpg
# ./LSTM_PIC/waistup/9/A (2).jpg
# ./LSTM_PIC/waistup/9/A (20).jpg
# ./LSTM_PIC/waistup/9/A (21).jpg
# ./LSTM_PIC/waistup/9/A (22).jpg
# ./LSTM_PIC/waistup/9/A (23).jpg
# ./LSTM_PIC/waistup/9/A (24).jpg
# ./LSTM_PIC/waistup/9/A (25).jpg
# ./LSTM_PIC/waistup/9/A (26).jpg
# ./LSTM_PIC/waistup/9/A (27).jpg
# ./LSTM_PIC/waistup/9/A (28).jpg
# ./LSTM_PIC/waistup/9/A (29).jpg
# ./LSTM_PIC/waistup/9/A (3).jpg
# ./LSTM_PIC/waistup/9/A (30).jpg
# ./LSTM_PIC/waistup/9/A (4).jpg
# ./LSTM_PIC/waistup/9/A (5).jpg
# ./LSTM_PIC/waistup/9/A (6).jpg
# ./LSTM_PIC/waistup/9/A (7).jpg
# ./LSTM_PIC/waistup/9/A (8).jpg
# ./LSTM_PIC/waistup/9/A (9).jpg

# %%
# 전처리, 특성, 라벨 생성
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
# actions 메핑하기 
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'bend': 0, 'headup': 1, 'right': 2, 'waistup': 3}

# %%
np.load("LSTM_DATAS/bend/0/f('bend', 0).npy")
# Out:
# array([137.22032547, 140.01979451, -28.        ])

# %%
np.load(f"{data_key}/{action}/{sequence}/f('{action}', {frame_num}).npy")
# Out:
# array([ 173.78558261,  111.36687222, -113.        ])

# %%
sequences, labels = [],[]
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequences_length):
            res = np.load(f"{data_key}/{action}/{sequence}/f('{action}', {frame_num}).npy")
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# action(4) * 10개의 폴더 , 30개의 사진 , 3개의 각도
# Out:
# (40, 30, 3)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,3)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 3s 405ms/step - loss: 159.4067 - categorical_accuracy: 0.2368
# Epoch 2/2000
# 2/2 [==============================] - 1s 386ms/step - loss: 32.8712 - categorical_accuracy: 0.2632
# Epoch 3/2000
# 2/2 [==============================] - 1s 289ms/step - loss: 30.8495 - categorical_accuracy: 0.3684
# Epoch 4/2000
# 2/2 [==============================] - 1s 339ms/step - loss: 33.0871 - categorical_accuracy: 0.2105
# Epoch 5/2000
# 2/2 [==============================] - 1s 272ms/step - loss: 31.4215 - categorical_accuracy: 0.2632
# Epoch 6/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 25.9466 - categorical_accuracy: 0.1579
# Epoch 7/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 30.4060 - categorical_accuracy: 0.2368
# Epoch 8/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 32.6087 - categorical_accuracy: 0.2105
# Epoch 9/2000
# 2/2 [==============================] - 1s 281ms/step - loss: 39.5330 - categorical_accuracy: 0.2632
# Epoch 10/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 36.2470 - categorical_accuracy: 0.2105
# Epoch 11/2000
# 2/2 [==============================] - 1s 322ms/step - loss: 32.7558 - categorical_accuracy: 0.2368
# Epoch 12/2000
# 2/2 [==============================] - 1s 288ms/step - loss: 27.2334 - categorical_accuracy: 0.2895
# Epoch 13/2000
# 2/2 [==============================] - 1s 287ms/step - loss: 31.6256 - categorical_accuracy: 0.2105
# Epoch 14/2000
# 2/2 [==============================] - 1s 289ms/step - loss: 39.8077 - categorical_accuracy: 0.3947
# Epoch 15/2000
# 2/2 [==============================] - 1s 376ms/step - loss: 19.2532 - categorical_accuracy: 0.4211
# Epoch 16/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 71.0641 - categorical_accuracy: 0.2368
# Epoch 17/2000
# 2/2 [==============================] - 1s 322ms/step - loss: 66.2278 - categorical_accuracy: 0.3947
# Epoch 18/2000
# 2/2 [==============================] - 1s 372ms/step - loss: 39.0365 - categorical_accuracy: 0.3684
# Epoch 19/2000
# 2/2 [==============================] - 1s 376ms/step - loss: 22.6460 - categorical_accuracy: 0.3684
# Epoch 20/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 27.9595 - categorical_accuracy: 0.3421
# Epoch 21/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 36.6339 - categorical_accuracy: 0.3421
# Epoch 22/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 20.3242 - categorical_accuracy: 0.3158
# Epoch 23/2000
# 2/2 [==============================] - 1s 336ms/step - loss: 27.9550 - categorical_accuracy: 0.4474
# Epoch 24/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 29.5575 - categorical_accuracy: 0.2895
# Epoch 25/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 34.3281 - categorical_accuracy: 0.2632
# Epoch 26/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 45.3935 - categorical_accuracy: 0.3421
# Epoch 27/2000
# 2/2 [==============================] - 1s 293ms/step - loss: 38.1322 - categorical_accuracy: 0.3158
# Epoch 28/2000
# 2/2 [==============================] - 1s 288ms/step - loss: 35.6190 - categorical_accuracy: 0.3421
# Epoch 29/2000
# 2/2 [==============================] - 1s 291ms/step - loss: 46.9823 - categorical_accuracy: 0.3684
# Epoch 30/2000
# 2/2 [==============================] - 1s 307ms/step - loss: 56.0359 - categorical_accuracy: 0.2368
# Epoch 31/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 56.3869 - categorical_accuracy: 0.3158
# Epoch 32/2000
# 2/2 [==============================] - 1s 286ms/step - loss: 54.3071 - categorical_accuracy: 0.3421
# Epoch 33/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 66.4135 - categorical_accuracy: 0.2368
# Epoch 34/2000
# 2/2 [==============================] - 1s 342ms/step - loss: 142.2173 - categorical_accuracy: 0.2368
# Epoch 35/2000
# 2/2 [==============================] - 1s 366ms/step - loss: 252.0462 - categorical_accuracy: 0.2105
# Epoch 36/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 67.8728 - categorical_accuracy: 0.4474
# Epoch 37/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 64.5953 - categorical_accuracy: 0.2895
# Epoch 38/2000
# 2/2 [==============================] - 1s 393ms/step - loss: 55.1589 - categorical_accuracy: 0.2895
# Epoch 39/2000
# 2/2 [==============================] - 1s 377ms/step - loss: 119.2252 - categorical_accuracy: 0.1842
# Epoch 40/2000
# 2/2 [==============================] - 1s 413ms/step - loss: 87.3781 - categorical_accuracy: 0.3421
# Epoch 41/2000
# 2/2 [==============================] - 1s 347ms/step - loss: 91.9760 - categorical_accuracy: 0.2895
# Epoch 42/2000
# 2/2 [==============================] - 1s 378ms/step - loss: 97.6770 - categorical_accuracy: 0.2632
# Epoch 43/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 106.2015 - categorical_accuracy: 0.3947
# Epoch 44/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 109.3862 - categorical_accuracy: 0.3421
# Epoch 45/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 91.4899 - categorical_accuracy: 0.5263
# Epoch 46/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 90.2750 - categorical_accuracy: 0.3158
# Epoch 47/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 55.7589 - categorical_accuracy: 0.4737
# Epoch 48/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 43.6502 - categorical_accuracy: 0.3421
# Epoch 49/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 54.6399 - categorical_accuracy: 0.2632
# Epoch 50/2000
# 2/2 [==============================] - 1s 369ms/step - loss: 53.5865 - categorical_accuracy: 0.4211
# Epoch 51/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 46.8326 - categorical_accuracy: 0.3421
# Epoch 52/2000
# 2/2 [==============================] - 1s 307ms/step - loss: 61.2041 - categorical_accuracy: 0.3947
# Epoch 53/2000
# 2/2 [==============================] - 1s 387ms/step - loss: 73.9346 - categorical_accuracy: 0.2632
# Epoch 54/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 95.0895 - categorical_accuracy: 0.3421
# Epoch 55/2000
# 2/2 [==============================] - 1s 315ms/step - loss: 86.1456 - categorical_accuracy: 0.3947
# Epoch 56/2000
# 2/2 [==============================] - 1s 313ms/step - loss: 28.6896 - categorical_accuracy: 0.5526
# Epoch 57/2000
# 2/2 [==============================] - 1s 376ms/step - loss: 40.8185 - categorical_accuracy: 0.5526
# Epoch 58/2000
# 2/2 [==============================] - 1s 360ms/step - loss: 49.7287 - categorical_accuracy: 0.4211
# Epoch 59/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 97.2816 - categorical_accuracy: 0.3421
# Epoch 60/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 145.8912 - categorical_accuracy: 0.3684
# Epoch 61/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 116.7701 - categorical_accuracy: 0.2895
# Epoch 62/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 124.8543 - categorical_accuracy: 0.3158
# Epoch 63/2000
# 2/2 [==============================] - 1s 390ms/step - loss: 64.6970 - categorical_accuracy: 0.4211
# Epoch 64/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 54.8854 - categorical_accuracy: 0.4474
# Epoch 65/2000
# 2/2 [==============================] - 1s 326ms/step - loss: 77.8543 - categorical_accuracy: 0.2895
# Epoch 66/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 102.4127 - categorical_accuracy: 0.2895
# Epoch 67/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 116.7740 - categorical_accuracy: 0.2368
# Epoch 68/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 99.8973 - categorical_accuracy: 0.1579
# Epoch 69/2000
# 2/2 [==============================] - 1s 352ms/step - loss: 80.0104 - categorical_accuracy: 0.3158
# Epoch 70/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 112.1899 - categorical_accuracy: 0.2895
# Epoch 71/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 77.0684 - categorical_accuracy: 0.2632
# Epoch 72/2000
# 2/2 [==============================] - 1s 330ms/step - loss: 61.9096 - categorical_accuracy: 0.2632
# Epoch 73/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 70.8325 - categorical_accuracy: 0.1842
# Epoch 74/2000
# 2/2 [==============================] - 1s 380ms/step - loss: 61.5301 - categorical_accuracy: 0.1579
# Epoch 75/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 79.5854 - categorical_accuracy: 0.2632
# Epoch 76/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 83.5651 - categorical_accuracy: 0.2632
# Epoch 77/2000
# 2/2 [==============================] - 1s 281ms/step - loss: 193.6311 - categorical_accuracy: 0.2632
# Epoch 78/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 130.5119 - categorical_accuracy: 0.1316
# Epoch 79/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 83.1782 - categorical_accuracy: 0.2632
# Epoch 80/2000
# 2/2 [==============================] - 1s 355ms/step - loss: 61.7768 - categorical_accuracy: 0.2105
# Epoch 81/2000
# 2/2 [==============================] - 1s 368ms/step - loss: 57.5167 - categorical_accuracy: 0.3158
# Epoch 82/2000
# 2/2 [==============================] - 1s 341ms/step - loss: 54.9206 - categorical_accuracy: 0.3421
# Epoch 83/2000
# 2/2 [==============================] - 1s 386ms/step - loss: 41.4859 - categorical_accuracy: 0.3421
# Epoch 84/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 46.3769 - categorical_accuracy: 0.3421
# Epoch 85/2000
# 2/2 [==============================] - 1s 383ms/step - loss: 41.4880 - categorical_accuracy: 0.2632
# Epoch 86/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 48.0900 - categorical_accuracy: 0.2368
# Epoch 87/2000
# 2/2 [==============================] - 1s 281ms/step - loss: 27.7124 - categorical_accuracy: 0.2632
# Epoch 88/2000
# 2/2 [==============================] - 1s 288ms/step - loss: 26.4427 - categorical_accuracy: 0.2368
# Epoch 89/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 27.9402 - categorical_accuracy: 0.3421
# Epoch 90/2000
# 2/2 [==============================] - 1s 283ms/step - loss: 33.3922 - categorical_accuracy: 0.3158
# Epoch 91/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 24.8555 - categorical_accuracy: 0.3684
# Epoch 92/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 14.2869 - categorical_accuracy: 0.2632
# Epoch 93/2000
# 2/2 [==============================] - 1s 320ms/step - loss: 22.4133 - categorical_accuracy: 0.2632
# Epoch 94/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 20.2477 - categorical_accuracy: 0.3158
# Epoch 95/2000
# 2/2 [==============================] - 1s 264ms/step - loss: 13.8637 - categorical_accuracy: 0.2895
# Epoch 96/2000
# 2/2 [==============================] - 1s 352ms/step - loss: 18.2073 - categorical_accuracy: 0.2368
# Epoch 97/2000
# 2/2 [==============================] - 1s 379ms/step - loss: 13.4486 - categorical_accuracy: 0.3947
# Epoch 98/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 9.9882 - categorical_accuracy: 0.5526
# Epoch 99/2000
# 2/2 [==============================] - 1s 284ms/step - loss: 13.3353 - categorical_accuracy: 0.3684
# Epoch 100/2000
# 2/2 [==============================] - 1s 340ms/step - loss: 11.5460 - categorical_accuracy: 0.3421
# Epoch 101/2000
# 2/2 [==============================] - 1s 351ms/step - loss: 9.7452 - categorical_accuracy: 0.4737
# Epoch 102/2000
# 2/2 [==============================] - 1s 346ms/step - loss: 10.2366 - categorical_accuracy: 0.5526
# Epoch 103/2000
# 2/2 [==============================] - 1s 255ms/step - loss: 9.1697 - categorical_accuracy: 0.4737
# Epoch 104/2000
# 2/2 [==============================] - 1s 335ms/step - loss: 15.7488 - categorical_accuracy: 0.4211
# Epoch 105/2000
# 2/2 [==============================] - 1s 266ms/step - loss: 16.6450 - categorical_accuracy: 0.4737
# Epoch 106/2000
# 2/2 [==============================] - 1s 278ms/step - loss: 13.9584 - categorical_accuracy: 0.5000
# Epoch 107/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 10.5550 - categorical_accuracy: 0.5526
# Epoch 108/2000
# 2/2 [==============================] - 1s 407ms/step - loss: 12.1726 - categorical_accuracy: 0.3947
# Epoch 109/2000
# 2/2 [==============================] - 1s 313ms/step - loss: 9.1609 - categorical_accuracy: 0.3158
# Epoch 110/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 7.8229 - categorical_accuracy: 0.5263
# Epoch 111/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 9.6198 - categorical_accuracy: 0.3684
# Epoch 112/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 6.6668 - categorical_accuracy: 0.4737
# Epoch 113/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 10.0881 - categorical_accuracy: 0.5000
# Epoch 114/2000
# 2/2 [==============================] - 1s 341ms/step - loss: 11.2147 - categorical_accuracy: 0.3684
# Epoch 115/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 6.0595 - categorical_accuracy: 0.4737
# Epoch 116/2000
# 2/2 [==============================] - 1s 281ms/step - loss: 15.3647 - categorical_accuracy: 0.3684
# Epoch 117/2000
# 2/2 [==============================] - 1s 276ms/step - loss: 10.9577 - categorical_accuracy: 0.5000
# Epoch 118/2000
# 2/2 [==============================] - 1s 287ms/step - loss: 8.8150 - categorical_accuracy: 0.5263
# Epoch 119/2000
# 2/2 [==============================] - 1s 375ms/step - loss: 16.3616 - categorical_accuracy: 0.2895
# Epoch 120/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 15.3917 - categorical_accuracy: 0.3684
# Epoch 121/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 18.1509 - categorical_accuracy: 0.5526
# Epoch 122/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 28.6709 - categorical_accuracy: 0.3158
# Epoch 123/2000
# 2/2 [==============================] - 1s 283ms/step - loss: 20.1197 - categorical_accuracy: 0.5789
# Epoch 124/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 13.8579 - categorical_accuracy: 0.4474
# Epoch 125/2000
# 2/2 [==============================] - 1s 279ms/step - loss: 12.1808 - categorical_accuracy: 0.3158
# Epoch 126/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 12.7035 - categorical_accuracy: 0.3158
# Epoch 127/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 10.2123 - categorical_accuracy: 0.5000
# Epoch 128/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 10.2578 - categorical_accuracy: 0.3684
# Epoch 129/2000
# 2/2 [==============================] - 1s 291ms/step - loss: 11.6114 - categorical_accuracy: 0.4211
# Epoch 130/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 8.7166 - categorical_accuracy: 0.5526
# Epoch 131/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 47.4070 - categorical_accuracy: 0.3158
# Epoch 132/2000
# 2/2 [==============================] - 1s 293ms/step - loss: 129.2875 - categorical_accuracy: 0.2105
# Epoch 133/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 67.8196 - categorical_accuracy: 0.1842
# Epoch 134/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 28.2926 - categorical_accuracy: 0.5000
# Epoch 135/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 35.6736 - categorical_accuracy: 0.3684
# Epoch 136/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 31.0360 - categorical_accuracy: 0.3684
# Epoch 137/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 30.9828 - categorical_accuracy: 0.3158
# Epoch 138/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 20.4629 - categorical_accuracy: 0.5263
# Epoch 139/2000
# 2/2 [==============================] - 1s 346ms/step - loss: 26.9394 - categorical_accuracy: 0.3684
# Epoch 140/2000
# 2/2 [==============================] - 1s 344ms/step - loss: 25.7300 - categorical_accuracy: 0.4737
# Epoch 141/2000
# 2/2 [==============================] - 1s 293ms/step - loss: 23.1376 - categorical_accuracy: 0.4737
# Epoch 142/2000
# 2/2 [==============================] - 1s 279ms/step - loss: 31.3054 - categorical_accuracy: 0.3684
# Epoch 143/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 24.2773 - categorical_accuracy: 0.4737
# Epoch 144/2000
# 2/2 [==============================] - 1s 388ms/step - loss: 26.1137 - categorical_accuracy: 0.3947
# Epoch 145/2000
# 2/2 [==============================] - 1s 354ms/step - loss: 25.7327 - categorical_accuracy: 0.3684
# Epoch 146/2000
# 2/2 [==============================] - 1s 285ms/step - loss: 22.8632 - categorical_accuracy: 0.3158
# Epoch 147/2000
# 2/2 [==============================] - 1s 350ms/step - loss: 20.8177 - categorical_accuracy: 0.4211
# Epoch 148/2000
# 2/2 [==============================] - 1s 301ms/step - loss: 20.2463 - categorical_accuracy: 0.3947
# Epoch 149/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 22.5777 - categorical_accuracy: 0.3684
# Epoch 150/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 22.9914 - categorical_accuracy: 0.4211
# Epoch 151/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 19.1618 - categorical_accuracy: 0.5000
# Epoch 152/2000
# 2/2 [==============================] - 1s 320ms/step - loss: 13.8320 - categorical_accuracy: 0.4737
# Epoch 153/2000
# 2/2 [==============================] - 1s 281ms/step - loss: 18.3511 - categorical_accuracy: 0.3684
# Epoch 154/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 14.0078 - categorical_accuracy: 0.5263
# Epoch 155/2000
# 2/2 [==============================] - 1s 348ms/step - loss: 11.3143 - categorical_accuracy: 0.4211
# Epoch 156/2000
# 2/2 [==============================] - 1s 293ms/step - loss: 7.6023 - categorical_accuracy: 0.6316
# Epoch 157/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 8.7274 - categorical_accuracy: 0.5526
# Epoch 158/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 8.2363 - categorical_accuracy: 0.5789
# Epoch 159/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 11.3573 - categorical_accuracy: 0.5789
# Epoch 160/2000
# 2/2 [==============================] - 1s 369ms/step - loss: 7.4166 - categorical_accuracy: 0.5789
# Epoch 161/2000
# 2/2 [==============================] - 1s 422ms/step - loss: 10.6922 - categorical_accuracy: 0.4737
# Epoch 162/2000
# 2/2 [==============================] - 1s 342ms/step - loss: 5.4143 - categorical_accuracy: 0.6316
# Epoch 163/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 5.5939 - categorical_accuracy: 0.6842
# Epoch 164/2000
# 2/2 [==============================] - 1s 372ms/step - loss: 7.1807 - categorical_accuracy: 0.6579
# Epoch 165/2000
# 2/2 [==============================] - 1s 289ms/step - loss: 6.4693 - categorical_accuracy: 0.6316
# Epoch 166/2000
# 2/2 [==============================] - 1s 351ms/step - loss: 4.4416 - categorical_accuracy: 0.6316
# Epoch 167/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 2.8312 - categorical_accuracy: 0.7105
# Epoch 168/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 9.5561 - categorical_accuracy: 0.5263
# Epoch 169/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 14.1469 - categorical_accuracy: 0.4737
# Epoch 170/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 8.0337 - categorical_accuracy: 0.5789
# Epoch 171/2000
# 2/2 [==============================] - 1s 341ms/step - loss: 5.2202 - categorical_accuracy: 0.6579
# Epoch 172/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 8.3032 - categorical_accuracy: 0.6579
# Epoch 173/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 10.2660 - categorical_accuracy: 0.6053
# Epoch 174/2000
# 2/2 [==============================] - 1s 292ms/step - loss: 11.1315 - categorical_accuracy: 0.6053
# Epoch 175/2000
# 2/2 [==============================] - 1s 332ms/step - loss: 8.4807 - categorical_accuracy: 0.6579
# Epoch 176/2000
# 2/2 [==============================] - 1s 366ms/step - loss: 4.5425 - categorical_accuracy: 0.7105
# Epoch 177/2000
# 2/2 [==============================] - 1s 329ms/step - loss: 3.7626 - categorical_accuracy: 0.6053
# Epoch 178/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 9.0701 - categorical_accuracy: 0.4737
# Epoch 179/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 4.6928 - categorical_accuracy: 0.6842
# Epoch 180/2000
# 2/2 [==============================] - 1s 264ms/step - loss: 10.0554 - categorical_accuracy: 0.6316
# Epoch 181/2000
# 2/2 [==============================] - 1s 261ms/step - loss: 11.7921 - categorical_accuracy: 0.5263
# Epoch 182/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 10.3843 - categorical_accuracy: 0.6316
# Epoch 183/2000
# 2/2 [==============================] - 1s 354ms/step - loss: 6.3040 - categorical_accuracy: 0.6842
# Epoch 184/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 5.9873 - categorical_accuracy: 0.7368
# Epoch 185/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 11.2061 - categorical_accuracy: 0.4474
# Epoch 186/2000
# 2/2 [==============================] - 1s 317ms/step - loss: 5.9262 - categorical_accuracy: 0.6316
# Epoch 187/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 4.6183 - categorical_accuracy: 0.6842
# Epoch 188/2000
# 2/2 [==============================] - 1s 306ms/step - loss: 4.7764 - categorical_accuracy: 0.6842
# Epoch 189/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 8.2315 - categorical_accuracy: 0.5526
# Epoch 190/2000
# 2/2 [==============================] - 1s 381ms/step - loss: 4.9289 - categorical_accuracy: 0.5789
# Epoch 191/2000
# 2/2 [==============================] - 1s 403ms/step - loss: 3.4824 - categorical_accuracy: 0.6579
# Epoch 192/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 5.2621 - categorical_accuracy: 0.6316
# Epoch 193/2000
# 2/2 [==============================] - 1s 291ms/step - loss: 6.5135 - categorical_accuracy: 0.6579
# Epoch 194/2000
# 2/2 [==============================] - 1s 368ms/step - loss: 4.5039 - categorical_accuracy: 0.7105
# Epoch 195/2000
# 2/2 [==============================] - 1s 347ms/step - loss: 2.9863 - categorical_accuracy: 0.7895
# Epoch 196/2000
# 2/2 [==============================] - 1s 339ms/step - loss: 1.5523 - categorical_accuracy: 0.7632
# Epoch 197/2000
# 2/2 [==============================] - 1s 266ms/step - loss: 2.4615 - categorical_accuracy: 0.7895
# Epoch 198/2000
# 2/2 [==============================] - 1s 265ms/step - loss: 2.3830 - categorical_accuracy: 0.7105
# Epoch 199/2000
# 2/2 [==============================] - 1s 261ms/step - loss: 1.2371 - categorical_accuracy: 0.8158
# Epoch 200/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 2.1116 - categorical_accuracy: 0.6842
# Epoch 201/2000
# 2/2 [==============================] - 1s 335ms/step - loss: 2.6567 - categorical_accuracy: 0.7105
# Epoch 202/2000
# 2/2 [==============================] - 1s 324ms/step - loss: 1.2987 - categorical_accuracy: 0.8684
# Epoch 203/2000
# 2/2 [==============================] - 1s 355ms/step - loss: 2.3799 - categorical_accuracy: 0.6842
# Epoch 204/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 3.2745 - categorical_accuracy: 0.6053
# Epoch 205/2000
# 2/2 [==============================] - 1s 436ms/step - loss: 1.2959 - categorical_accuracy: 0.8158
# Epoch 206/2000
# 2/2 [==============================] - 1s 333ms/step - loss: 1.9157 - categorical_accuracy: 0.7368
# Epoch 207/2000
# 2/2 [==============================] - 1s 360ms/step - loss: 1.9186 - categorical_accuracy: 0.7368
# Epoch 208/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 1.8684 - categorical_accuracy: 0.7105
# Epoch 209/2000
# 2/2 [==============================] - 1s 421ms/step - loss: 2.4145 - categorical_accuracy: 0.8158
# Epoch 210/2000
# 2/2 [==============================] - 1s 289ms/step - loss: 1.6096 - categorical_accuracy: 0.7632
# Epoch 211/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 1.9150 - categorical_accuracy: 0.7105
# Epoch 212/2000
# 2/2 [==============================] - 1s 359ms/step - loss: 2.0663 - categorical_accuracy: 0.7368
# Epoch 213/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 0.6865 - categorical_accuracy: 0.8421
# Epoch 214/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 4.8139 - categorical_accuracy: 0.6842
# Epoch 215/2000
# 2/2 [==============================] - 1s 340ms/step - loss: 5.4174 - categorical_accuracy: 0.7105
# Epoch 216/2000
# 2/2 [==============================] - 1s 336ms/step - loss: 2.1947 - categorical_accuracy: 0.6579
# Epoch 217/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 3.8523 - categorical_accuracy: 0.6842
# Epoch 218/2000
# 2/2 [==============================] - 1s 391ms/step - loss: 1.4302 - categorical_accuracy: 0.7632
# Epoch 219/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 3.2154 - categorical_accuracy: 0.7368
# Epoch 220/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 4.3749 - categorical_accuracy: 0.7105
# Epoch 221/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 2.2091 - categorical_accuracy: 0.6842
# Epoch 222/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 5.5032 - categorical_accuracy: 0.7105
# Epoch 223/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 5.9317 - categorical_accuracy: 0.6842
# Epoch 224/2000
# 2/2 [==============================] - 1s 319ms/step - loss: 2.7016 - categorical_accuracy: 0.6842
# Epoch 225/2000
# 2/2 [==============================] - 1s 259ms/step - loss: 3.3838 - categorical_accuracy: 0.6579
# Epoch 226/2000
# 2/2 [==============================] - 1s 260ms/step - loss: 3.6411 - categorical_accuracy: 0.6579
# Epoch 227/2000
# 2/2 [==============================] - 1s 263ms/step - loss: 2.1326 - categorical_accuracy: 0.7105
# Epoch 228/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 3.0389 - categorical_accuracy: 0.6316
# Epoch 229/2000
# 2/2 [==============================] - 1s 280ms/step - loss: 1.9364 - categorical_accuracy: 0.7105
# Epoch 230/2000
# 2/2 [==============================] - 1s 285ms/step - loss: 2.1656 - categorical_accuracy: 0.6842
# Epoch 231/2000
# 2/2 [==============================] - 1s 364ms/step - loss: 1.0937 - categorical_accuracy: 0.7368
# Epoch 232/2000
# 2/2 [==============================] - 1s 390ms/step - loss: 1.6606 - categorical_accuracy: 0.6842
# Epoch 233/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.0042 - categorical_accuracy: 0.7105
# Epoch 234/2000
# 2/2 [==============================] - 1s 278ms/step - loss: 2.2340 - categorical_accuracy: 0.6579
# Epoch 235/2000
# 2/2 [==============================] - 1s 335ms/step - loss: 2.7860 - categorical_accuracy: 0.6842
# Epoch 236/2000
# 2/2 [==============================] - 1s 334ms/step - loss: 2.9298 - categorical_accuracy: 0.7632
# Epoch 237/2000
# 2/2 [==============================] - 1s 369ms/step - loss: 0.7685 - categorical_accuracy: 0.8421
# Epoch 238/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 2.8301 - categorical_accuracy: 0.7105
# Epoch 239/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 3.6964 - categorical_accuracy: 0.7368
# Epoch 240/2000
# 2/2 [==============================] - 1s 395ms/step - loss: 1.4195 - categorical_accuracy: 0.8421
# Epoch 241/2000
# 2/2 [==============================] - 1s 280ms/step - loss: 1.6125 - categorical_accuracy: 0.8421
# Epoch 242/2000
# 2/2 [==============================] - 1s 351ms/step - loss: 2.4019 - categorical_accuracy: 0.6842
# Epoch 243/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 0.9762 - categorical_accuracy: 0.7368
# Epoch 244/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 2.8372 - categorical_accuracy: 0.7368
# Epoch 245/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 1.8408 - categorical_accuracy: 0.7632
# Epoch 246/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 4.2155 - categorical_accuracy: 0.5263
# Epoch 247/2000
# 2/2 [==============================] - 1s 341ms/step - loss: 4.7820 - categorical_accuracy: 0.6053
# Epoch 248/2000
# 2/2 [==============================] - 1s 379ms/step - loss: 3.2041 - categorical_accuracy: 0.7105
# Epoch 249/2000
# 2/2 [==============================] - 1s 366ms/step - loss: 4.9573 - categorical_accuracy: 0.5789
# Epoch 250/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 1.1739 - categorical_accuracy: 0.7632
# Epoch 251/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 3.2547 - categorical_accuracy: 0.6579
# Epoch 252/2000
# 2/2 [==============================] - 1s 369ms/step - loss: 1.8918 - categorical_accuracy: 0.8158
# Epoch 253/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 1.6676 - categorical_accuracy: 0.8158
# Epoch 254/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 1.3671 - categorical_accuracy: 0.7368
# Epoch 255/2000
# 2/2 [==============================] - 1s 317ms/step - loss: 0.9783 - categorical_accuracy: 0.7632
# Epoch 256/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 0.8811 - categorical_accuracy: 0.8421
# Epoch 257/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 0.9400 - categorical_accuracy: 0.7895
# Epoch 258/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 0.8008 - categorical_accuracy: 0.8421
# Epoch 259/2000
# 2/2 [==============================] - 1s 386ms/step - loss: 0.3145 - categorical_accuracy: 0.8947
# Epoch 260/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 0.8269 - categorical_accuracy: 0.7895
# Epoch 261/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 0.8471 - categorical_accuracy: 0.8158
# Epoch 262/2000
# 2/2 [==============================] - 1s 294ms/step - loss: 0.7332 - categorical_accuracy: 0.8421
# Epoch 263/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 0.3268 - categorical_accuracy: 0.8947
# Epoch 264/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 0.5481 - categorical_accuracy: 0.8421
# Epoch 265/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 0.6600 - categorical_accuracy: 0.8947
# Epoch 266/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 0.4531 - categorical_accuracy: 0.8684
# Epoch 267/2000
# 2/2 [==============================] - 1s 382ms/step - loss: 1.4038 - categorical_accuracy: 0.7368
# Epoch 268/2000
# 2/2 [==============================] - 1s 320ms/step - loss: 0.7785 - categorical_accuracy: 0.8158
# Epoch 269/2000
# 2/2 [==============================] - 1s 390ms/step - loss: 0.6317 - categorical_accuracy: 0.8684
# Epoch 270/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 0.5887 - categorical_accuracy: 0.8421
# Epoch 271/2000
# 2/2 [==============================] - 1s 397ms/step - loss: 0.1716 - categorical_accuracy: 0.8947
# Epoch 272/2000
# 2/2 [==============================] - 1s 387ms/step - loss: 1.4175 - categorical_accuracy: 0.7895
# Epoch 273/2000
# 2/2 [==============================] - 1s 377ms/step - loss: 0.7361 - categorical_accuracy: 0.7895
# Epoch 274/2000
# 2/2 [==============================] - 1s 377ms/step - loss: 1.1228 - categorical_accuracy: 0.8158
# Epoch 275/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 3.6233 - categorical_accuracy: 0.7632
# Epoch 276/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 2.3886 - categorical_accuracy: 0.7632
# Epoch 277/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 0.7588 - categorical_accuracy: 0.8947
# Epoch 278/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 1.7949 - categorical_accuracy: 0.7632
# Epoch 279/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 4.4420 - categorical_accuracy: 0.5526
# Epoch 280/2000
# 2/2 [==============================] - 1s 338ms/step - loss: 3.1344 - categorical_accuracy: 0.5789
# Epoch 281/2000
# 2/2 [==============================] - 1s 322ms/step - loss: 4.0894 - categorical_accuracy: 0.6053
# Epoch 282/2000
# 2/2 [==============================] - 1s 317ms/step - loss: 1.2278 - categorical_accuracy: 0.7632
# Epoch 283/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 3.0222 - categorical_accuracy: 0.7368
# Epoch 284/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 4.9800 - categorical_accuracy: 0.5789
# Epoch 285/2000
# 2/2 [==============================] - 1s 333ms/step - loss: 2.6846 - categorical_accuracy: 0.7632
# Epoch 286/2000
# 2/2 [==============================] - 1s 379ms/step - loss: 1.6348 - categorical_accuracy: 0.7632
# Epoch 287/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 0.9631 - categorical_accuracy: 0.8421
# Epoch 288/2000
# 2/2 [==============================] - 1s 284ms/step - loss: 5.2669 - categorical_accuracy: 0.5263
# Epoch 289/2000
# 2/2 [==============================] - 1s 402ms/step - loss: 1.9562 - categorical_accuracy: 0.7895
# Epoch 290/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 3.1930 - categorical_accuracy: 0.7632
# Epoch 291/2000
# 2/2 [==============================] - 1s 375ms/step - loss: 4.6357 - categorical_accuracy: 0.6842
# Epoch 292/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 4.2721 - categorical_accuracy: 0.7105
# Epoch 293/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 3.4940 - categorical_accuracy: 0.7632
# Epoch 294/2000
# 2/2 [==============================] - 1s 274ms/step - loss: 2.4085 - categorical_accuracy: 0.7895
# Epoch 295/2000
# 2/2 [==============================] - 1s 276ms/step - loss: 0.8233 - categorical_accuracy: 0.8684
# Epoch 296/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 3.2789 - categorical_accuracy: 0.6842
# Epoch 297/2000
# 2/2 [==============================] - 1s 382ms/step - loss: 1.4775 - categorical_accuracy: 0.7368
# Epoch 298/2000
# 2/2 [==============================] - 1s 371ms/step - loss: 1.6631 - categorical_accuracy: 0.8158
# Epoch 299/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 1.4711 - categorical_accuracy: 0.8158
# Epoch 300/2000
# 2/2 [==============================] - 1s 324ms/step - loss: 2.7534 - categorical_accuracy: 0.7368
# Epoch 301/2000
# 2/2 [==============================] - 1s 320ms/step - loss: 1.5906 - categorical_accuracy: 0.7895
# Epoch 302/2000
# 2/2 [==============================] - 1s 385ms/step - loss: 1.4854 - categorical_accuracy: 0.7632
# Epoch 303/2000
# 2/2 [==============================] - 1s 409ms/step - loss: 1.9422 - categorical_accuracy: 0.6842
# Epoch 304/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 0.7857 - categorical_accuracy: 0.8421
# Epoch 305/2000
# 2/2 [==============================] - 1s 260ms/step - loss: 0.3752 - categorical_accuracy: 0.8947
# Epoch 306/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 1.3230 - categorical_accuracy: 0.8684
# Epoch 307/2000
# 2/2 [==============================] - 1s 274ms/step - loss: 3.5693 - categorical_accuracy: 0.7368
# Epoch 308/2000
# 2/2 [==============================] - 1s 274ms/step - loss: 2.0181 - categorical_accuracy: 0.8421
# Epoch 309/2000
# 2/2 [==============================] - 1s 335ms/step - loss: 2.3672 - categorical_accuracy: 0.7632
# Epoch 310/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 0.8143 - categorical_accuracy: 0.7895
# Epoch 311/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 3.8828 - categorical_accuracy: 0.6316
# Epoch 312/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 0.8343 - categorical_accuracy: 0.8684
# Epoch 313/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 0.9348 - categorical_accuracy: 0.7895
# Epoch 314/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 1.6225 - categorical_accuracy: 0.6842
# Epoch 315/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 0.5921 - categorical_accuracy: 0.8947
# Epoch 316/2000
# 2/2 [==============================] - 1s 342ms/step - loss: 0.6134 - categorical_accuracy: 0.8947
# Epoch 317/2000
# 2/2 [==============================] - 1s 330ms/step - loss: 0.1305 - categorical_accuracy: 0.9474
# Epoch 318/2000
# 2/2 [==============================] - 1s 336ms/step - loss: 0.4354 - categorical_accuracy: 0.8421
# Epoch 319/2000
# 2/2 [==============================] - 1s 374ms/step - loss: 0.1712 - categorical_accuracy: 0.9737
# Epoch 320/2000
# 2/2 [==============================] - 1s 410ms/step - loss: 0.5356 - categorical_accuracy: 0.9474
# Epoch 321/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 0.3156 - categorical_accuracy: 0.9474
# Epoch 322/2000
# 2/2 [==============================] - 1s 315ms/step - loss: 0.4141 - categorical_accuracy: 0.8947
# Epoch 323/2000
# 2/2 [==============================] - 1s 244ms/step - loss: 0.3105 - categorical_accuracy: 0.8947
# Epoch 324/2000
# 2/2 [==============================] - 1s 269ms/step - loss: 0.2212 - categorical_accuracy: 0.9474
# Epoch 325/2000
# 2/2 [==============================] - 1s 272ms/step - loss: 0.5067 - categorical_accuracy: 0.9211
# Epoch 326/2000
# 2/2 [==============================] - 1s 257ms/step - loss: 0.0646 - categorical_accuracy: 0.9737
# Epoch 327/2000
# 2/2 [==============================] - 1s 251ms/step - loss: 0.5934 - categorical_accuracy: 0.8684
# Epoch 328/2000
# 2/2 [==============================] - 1s 275ms/step - loss: 0.2091 - categorical_accuracy: 0.9211
# Epoch 329/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 0.0748 - categorical_accuracy: 0.9737
# Epoch 330/2000
# 2/2 [==============================] - 1s 343ms/step - loss: 0.2383 - categorical_accuracy: 0.9474
# Epoch 331/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 0.2518 - categorical_accuracy: 0.9211
# Epoch 332/2000
# 2/2 [==============================] - 1s 344ms/step - loss: 0.0267 - categorical_accuracy: 0.9737
# Epoch 333/2000
# 2/2 [==============================] - 1s 374ms/step - loss: 0.1565 - categorical_accuracy: 0.9737
# Epoch 334/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 0.0073 - categorical_accuracy: 1.0000
# Epoch 335/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0823 - categorical_accuracy: 0.9737
# Epoch 336/2000
# 2/2 [==============================] - 1s 426ms/step - loss: 0.3347 - categorical_accuracy: 0.9211
# Epoch 337/2000
# 2/2 [==============================] - 1s 317ms/step - loss: 0.1375 - categorical_accuracy: 0.9474
# Epoch 338/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 0.0095 - categorical_accuracy: 1.0000
# Epoch 339/2000
# 2/2 [==============================] - 1s 255ms/step - loss: 0.0736 - categorical_accuracy: 0.9737
# Epoch 340/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 0.1196 - categorical_accuracy: 0.9737
# Epoch 341/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 0.0436 - categorical_accuracy: 0.9737
# Epoch 342/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 0.0080 - categorical_accuracy: 1.0000
# Epoch 343/2000
# 2/2 [==============================] - 1s 322ms/step - loss: 0.0608 - categorical_accuracy: 0.9737
# Epoch 344/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 0.0736 - categorical_accuracy: 0.9737
# Epoch 345/2000
# 2/2 [==============================] - 1s 260ms/step - loss: 0.0298 - categorical_accuracy: 0.9737
# Epoch 346/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0092 - categorical_accuracy: 1.0000
# Epoch 347/2000
# 2/2 [==============================] - 1s 352ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 348/2000
# 2/2 [==============================] - 1s 336ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 349/2000
# 2/2 [==============================] - 1s 391ms/step - loss: 0.0048 - categorical_accuracy: 1.0000
# Epoch 350/2000
# 2/2 [==============================] - 1s 339ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 351/2000
# 2/2 [==============================] - 1s 323ms/step - loss: 0.0059 - categorical_accuracy: 1.0000
# Epoch 352/2000
# 2/2 [==============================] - 1s 389ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 353/2000
# 2/2 [==============================] - 1s 248ms/step - loss: 0.0046 - categorical_accuracy: 1.0000
# Epoch 354/2000
# 2/2 [==============================] - 1s 293ms/step - loss: 0.0102 - categorical_accuracy: 1.0000
# Epoch 355/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 0.0139 - categorical_accuracy: 1.0000
# Epoch 356/2000
# 2/2 [==============================] - 1s 326ms/step - loss: 0.0091 - categorical_accuracy: 1.0000
# Epoch 357/2000
# 2/2 [==============================] - 1s 355ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 358/2000
# 2/2 [==============================] - 1s 331ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 359/2000
# 2/2 [==============================] - 1s 334ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 360/2000
# 2/2 [==============================] - 1s 288ms/step - loss: 0.0061 - categorical_accuracy: 1.0000
# Epoch 361/2000
# 2/2 [==============================] - 1s 274ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 362/2000
# 2/2 [==============================] - 1s 341ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 363/2000
# 2/2 [==============================] - 1s 340ms/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 364/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 365/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 366/2000
# 2/2 [==============================] - 1s 265ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 367/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 368/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 371/2000
# 2/2 [==============================] - 1s 346ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 372/2000
# 2/2 [==============================] - 1s 288ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 373/2000
# 2/2 [==============================] - 1s 327ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 374/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 375/2000
# 2/2 [==============================] - 1s 319ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 376/2000
# 2/2 [==============================] - 1s 275ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 377/2000
# 2/2 [==============================] - 1s 307ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 378/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 0.0056 - categorical_accuracy: 1.0000
# Epoch 379/2000
# 2/2 [==============================] - 1s 336ms/step - loss: 0.0121 - categorical_accuracy: 1.0000
# Epoch 380/2000
# 2/2 [==============================] - 1s 277ms/step - loss: 0.0117 - categorical_accuracy: 1.0000
# Epoch 381/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 382/2000
# 2/2 [==============================] - 1s 268ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 2/2 [==============================] - 1s 290ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 384/2000
# 2/2 [==============================] - 1s 292ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 2/2 [==============================] - 1s 339ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 2/2 [==============================] - 1s 267ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0111 - categorical_accuracy: 1.0000
# Epoch 388/2000
# 2/2 [==============================] - 1s 274ms/step - loss: 0.0111 - categorical_accuracy: 1.0000
# Epoch 389/2000
# 2/2 [==============================] - 1s 285ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 390/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 0.0284 - categorical_accuracy: 0.9737
# Epoch 391/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 0.0579 - categorical_accuracy: 0.9737
# Epoch 392/2000
# 2/2 [==============================] - 1s 344ms/step - loss: 0.0260 - categorical_accuracy: 0.9737
# Epoch 393/2000
# 2/2 [==============================] - 1s 334ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 2/2 [==============================] - 1s 332ms/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 2/2 [==============================] - 1s 309ms/step - loss: 0.0184 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 2/2 [==============================] - 1s 334ms/step - loss: 0.0157 - categorical_accuracy: 1.0000
# Epoch 397/2000
# 2/2 [==============================] - 1s 289ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 2/2 [==============================] - 1s 333ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 2/2 [==============================] - 1s 326ms/step - loss: 0.0061 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 2/2 [==============================] - 1s 267ms/step - loss: 0.0067 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 2/2 [==============================] - 1s 282ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 2/2 [==============================] - 1s 344ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 2/2 [==============================] - 1s 335ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 2/2 [==============================] - 1s 279ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 2/2 [==============================] - 1s 283ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 2/2 [==============================] - 1s 267ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 2/2 [==============================] - 1s 272ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 2/2 [==============================] - 1s 272ms/step - loss: 0.0052 - categorical_accuracy: 1.0000
# Epoch 411/2000
# 2/2 [==============================] - 1s 323ms/step - loss: 0.0075 - categorical_accuracy: 1.0000
# Epoch 412/2000
# 2/2 [==============================] - 1s 386ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 413/2000
# 2/2 [==============================] - 1s 278ms/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 414/2000
# 2/2 [==============================] - 1s 276ms/step - loss: 0.0325 - categorical_accuracy: 0.9737
# Epoch 415/2000
# 2/2 [==============================] - 1s 273ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 416/2000
# 2/2 [==============================] - 1s 284ms/step - loss: 0.3234 - categorical_accuracy: 0.9474
# Epoch 417/2000
# 2/2 [==============================] - 1s 350ms/step - loss: 0.0133 - categorical_accuracy: 1.0000
# Epoch 418/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 1.5899 - categorical_accuracy: 0.8421
# Epoch 419/2000
# 2/2 [==============================] - 1s 266ms/step - loss: 0.7274 - categorical_accuracy: 0.8947
# Epoch 420/2000
# 2/2 [==============================] - 1s 319ms/step - loss: 0.9547 - categorical_accuracy: 0.8947
# Epoch 421/2000
# ...
# Epoch 1867/2000
# 2/2 [==============================] - 1s 307ms/step - loss: 2.6660e-05 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 2/2 [==============================] - 1s 329ms/step - loss: 2.6610e-05 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 2/2 [==============================] - 1s 306ms/step - loss: 2.6600e-05 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 2.6597e-05 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 2.6588e-05 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.6572e-05 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 2/2 [==============================] - 1s 347ms/step - loss: 2.6663e-05 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 2/2 [==============================] - 1s 351ms/step - loss: 2.6657e-05 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 2.6619e-05 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 2.6584e-05 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 2/2 [==============================] - 1s 291ms/step - loss: 2.6572e-05 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 2/2 [==============================] - 1s 394ms/step - loss: 2.6512e-05 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 2.6509e-05 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 2/2 [==============================] - 1s 307ms/step - loss: 2.6541e-05 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 2/2 [==============================] - 1s 332ms/step - loss: 2.6528e-05 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 2/2 [==============================] - 1s 306ms/step - loss: 2.6478e-05 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 2/2 [==============================] - 1s 360ms/step - loss: 2.6503e-05 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 2/2 [==============================] - 1s 381ms/step - loss: 2.6468e-05 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 2/2 [==============================] - 1s 396ms/step - loss: 2.6462e-05 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 2/2 [==============================] - 1s 333ms/step - loss: 2.6450e-05 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 2.6487e-05 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 2/2 [==============================] - 1s 333ms/step - loss: 2.6434e-05 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.6415e-05 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.6531e-05 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 2.6409e-05 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 2/2 [==============================] - 1s 377ms/step - loss: 2.6396e-05 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 2/2 [==============================] - 1s 412ms/step - loss: 2.6387e-05 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 2.6425e-05 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 2.6393e-05 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 2.6393e-05 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 2.6371e-05 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 2/2 [==============================] - 1s 369ms/step - loss: 2.6359e-05 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 2.6352e-05 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 2.6387e-05 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 2.6327e-05 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 2/2 [==============================] - 1s 325ms/step - loss: 2.6324e-05 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 2.6305e-05 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 2.6305e-05 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 2.6346e-05 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 2.6302e-05 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 2/2 [==============================] - 1s 360ms/step - loss: 2.6315e-05 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 2/2 [==============================] - 1s 355ms/step - loss: 2.6287e-05 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 2/2 [==============================] - 1s 374ms/step - loss: 2.6280e-05 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 2/2 [==============================] - 1s 339ms/step - loss: 2.6277e-05 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 2/2 [==============================] - 1s 312ms/step - loss: 2.6265e-05 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 2/2 [==============================] - 1s 330ms/step - loss: 2.6258e-05 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 2/2 [==============================] - 1s 389ms/step - loss: 2.6258e-05 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 2/2 [==============================] - 1s 368ms/step - loss: 2.6265e-05 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 2/2 [==============================] - 1s 421ms/step - loss: 2.6249e-05 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 2/2 [==============================] - 1s 296ms/step - loss: 2.6233e-05 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 2.6227e-05 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 2/2 [==============================] - 1s 400ms/step - loss: 2.6202e-05 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 2/2 [==============================] - 1s 295ms/step - loss: 2.6211e-05 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 2/2 [==============================] - 1s 364ms/step - loss: 2.6177e-05 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 2/2 [==============================] - 1s 382ms/step - loss: 2.6268e-05 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 2/2 [==============================] - 1s 314ms/step - loss: 2.6218e-05 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 2/2 [==============================] - 1s 301ms/step - loss: 2.6211e-05 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 2/2 [==============================] - 1s 372ms/step - loss: 2.6189e-05 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 2/2 [==============================] - 1s 318ms/step - loss: 2.6167e-05 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 2.6202e-05 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 2/2 [==============================] - 1s 366ms/step - loss: 2.6139e-05 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 2/2 [==============================] - 1s 313ms/step - loss: 2.6142e-05 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 2.6117e-05 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 2/2 [==============================] - 1s 299ms/step - loss: 2.6108e-05 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 2/2 [==============================] - 1s 315ms/step - loss: 2.6108e-05 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 2/2 [==============================] - 1s 319ms/step - loss: 2.6067e-05 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 2.6114e-05 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 2/2 [==============================] - 1s 315ms/step - loss: 2.6079e-05 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 2.6092e-05 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 2.6101e-05 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 2/2 [==============================] - 1s 298ms/step - loss: 2.6054e-05 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 2/2 [==============================] - 1s 324ms/step - loss: 2.6051e-05 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 2/2 [==============================] - 1s 297ms/step - loss: 2.6042e-05 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 2/2 [==============================] - 1s 296ms/step - loss: 2.6039e-05 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 2/2 [==============================] - 1s 351ms/step - loss: 2.6032e-05 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 2/2 [==============================] - 1s 373ms/step - loss: 2.5982e-05 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 2/2 [==============================] - 1s 350ms/step - loss: 2.6051e-05 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 2.5976e-05 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 2/2 [==============================] - 1s 313ms/step - loss: 2.5957e-05 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 2.6010e-05 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.5973e-05 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 2/2 [==============================] - 1s 392ms/step - loss: 2.5960e-05 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 2.5957e-05 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 2.5948e-05 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 2.5926e-05 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 2.5926e-05 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 2/2 [==============================] - 1s 354ms/step - loss: 2.5904e-05 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 2/2 [==============================] - 1s 361ms/step - loss: 2.5913e-05 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 2.5901e-05 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 2/2 [==============================] - 1s 317ms/step - loss: 2.5901e-05 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 2/2 [==============================] - 1s 345ms/step - loss: 2.5898e-05 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 2/2 [==============================] - 1s 331ms/step - loss: 2.5891e-05 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 2/2 [==============================] - 1s 381ms/step - loss: 2.5879e-05 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 2.6032e-05 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.5901e-05 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 2/2 [==============================] - 1s 303ms/step - loss: 2.5923e-05 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 2/2 [==============================] - 1s 410ms/step - loss: 2.5863e-05 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 2.5866e-05 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 2/2 [==============================] - 1s 362ms/step - loss: 2.5910e-05 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 2/2 [==============================] - 1s 374ms/step - loss: 2.5891e-05 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 2.5910e-05 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 2/2 [==============================] - 1s 328ms/step - loss: 2.5879e-05 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 2/2 [==============================] - 1s 380ms/step - loss: 2.5854e-05 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 2/2 [==============================] - 1s 371ms/step - loss: 2.5835e-05 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 2/2 [==============================] - 1s 353ms/step - loss: 2.5819e-05 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 2/2 [==============================] - 1s 375ms/step - loss: 2.5800e-05 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 2/2 [==============================] - 1s 370ms/step - loss: 2.5769e-05 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 2/2 [==============================] - 1s 419ms/step - loss: 2.5772e-05 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 2/2 [==============================] - 1s 359ms/step - loss: 2.5734e-05 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 2/2 [==============================] - 1s 356ms/step - loss: 2.5835e-05 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 2/2 [==============================] - 1s 380ms/step - loss: 2.5769e-05 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 2/2 [==============================] - 1s 364ms/step - loss: 2.5760e-05 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 2/2 [==============================] - 1s 379ms/step - loss: 2.5760e-05 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 2/2 [==============================] - 1s 374ms/step - loss: 2.5756e-05 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 2/2 [==============================] - 1s 363ms/step - loss: 2.5753e-05 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 2.5750e-05 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 2/2 [==============================] - 1s 305ms/step - loss: 2.5719e-05 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 2/2 [==============================] - 1s 311ms/step - loss: 2.5835e-05 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 2/2 [==============================] - 1s 365ms/step - loss: 2.5791e-05 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 2/2 [==============================] - 1s 362ms/step - loss: 2.5810e-05 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 2/2 [==============================] - 1s 367ms/step - loss: 2.5763e-05 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 2/2 [==============================] - 1s 400ms/step - loss: 2.5750e-05 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 2/2 [==============================] - 1s 304ms/step - loss: 2.5747e-05 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 2.5750e-05 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 2/2 [==============================] - 1s 321ms/step - loss: 2.5775e-05 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 2/2 [==============================] - 1s 316ms/step - loss: 2.5744e-05 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 2/2 [==============================] - 1s 302ms/step - loss: 2.5712e-05 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 2/2 [==============================] - 1s 308ms/step - loss: 2.5687e-05 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 2/2 [==============================] - 1s 306ms/step - loss: 2.5669e-05 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 2/2 [==============================] - 1s 381ms/step - loss: 2.5643e-05 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 2/2 [==============================] - 1s 357ms/step - loss: 2.5640e-05 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 2/2 [==============================] - 1s 310ms/step - loss: 2.5631e-05 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 2/2 [==============================] - 1s 300ms/step - loss: 2.5571e-05 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 2/2 [==============================] - 1s 358ms/step - loss: 2.5584e-05 - categorical_accuracy: 1.0000

# %%
r= model.predict(X_test)
r.argmax()
# Out:
# 1/1 [==============================] - 0s 67ms/step
# 2
